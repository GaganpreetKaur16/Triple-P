# %% [markdown]
# # Business Problem

# %% [markdown]
# Using Machine Learning , trying to predict the sale price of the properties.

# %% [markdown]
# # About the Dataset used in the problem

# %% [markdown]
# About the dataset- Origionally the dateset is from
#
# https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page
#
# I have downloaded it from Kaggle- https://www.kaggle.com/new-york-city/nyc-property-sales
#
# Properties sold in New York City over a 12-month period from September 2016 to September 2017.
#
#
# GLOSSARY OF TERMS taken from https://www1.nyc.gov/assets/finance/downloads/pdf/07pdf/glossary_rsf071607.pdf
# The following terms follow the column headings across the spreadsheet, from left to right.
#
#     1. Borough:  The name of the borough in which the property is located.
#
#     2. Neighborhood: Department of Finance assessors determine the neighborhood name in the course of valuing properties.  The  common  name  of  the  neighborhood  is  generally  the  same  as  the  name  Finance designates. However, there may be slight differences in neighborhood boundary lines and some sub-neighborhoods may not be included.
#
#     3. Building Class Category: This  is  a  field  that  we  are  including  so  that  users  of  the  Rolling  Sales  Files  can  easily  identify  similar  properties  by  broad  usage  (e.g.  One  Family  Homes)  without  looking  up  individual  Building  Classes.  Files  are  sorted  by  Borough,  Neighborhood,  Building  Class  Category, Block and Lot.
#
#     4. Tax Class at Present: Every  property  in  the  city  is  assigned  to  one  of  four  tax  classes  (Classes  1,  2,  3,  and  4),  based on the use of the property.
#     • Class  1:  Includes  most  residential  property  of  up  to  three  units  (such  as  one-,  two-,  and  three-family  homes  and  small  stores  or  offices  with  one  or  two  attached  apartments),  vacant  land  that  is  zoned  for  residential  use,  and  most  condominiums that are not more than three stories.
#     • Class  2:  Includes  all  other  property  that  is  primarily  residential,  such  as  cooperatives and condominiums.
#     • Class 3: Includes property with equipment owned by a gas, telephone or electric company.
#     • Class  4:  Includes  all  other  properties  not  included  in  class  1,2,  and  3,  such  as  offices, factories, warehouses, garage buildings, etc.  Glossary of Terms for Property Sales Files
#
#     5. Block: A Tax Block is a sub-division of the borough on which real properties are located. The  Department  of  Finance  uses  a  Borough-Block-Lot  classification  to  label  all  real  property  in  the  City.  “Whereas”  addresses  describe  the  street  location  of  a  property,  the  block  and  lot  distinguishes  one  unit  of  real  property  from  another,  such  as  the  different  condominiums  in  a  single  building.  Also,  block  and  lots  are  not  subject  to  name  changes  based on which side of the parcel the building puts its entrance on.
#
#     6. Lot:   A Tax Lot is a subdivision of a Tax Block and represents the property unique location.
#
#     7. Easement:    An easement is a right, such as a right of way, which allows an entity to make limited use of another’s real property.For example:  MTA railroad tracks that run across a portion of another property.
#
#     8. Building Class at Present: The Building Classification is used to describe a property’s constructive use. The first position of  the  Building  Class  is  a  letter  that  is  used  to  describe  a  general  class  of  properties  (for  example   “A”   signifies   one-family   homes,   “O”   signifies   office   buildings.   “R”   signifies   condominiums).  The  second  position,  a  number,  adds  more  specific  information  about  the  property’s  use  or  construction  style  (using  our  previous  examples  “A0”  is  a  Cape  Cod  style  one family home, “O4” is a tower type office building and “R5” is a commercial condominium unit). The term Building Class used by the Department of Finance is interchangeable with the term Building Code used by the Department of Buildings. See NYC Building Classifications.
#
#     9. Address:    The  street  address  of  the  property  as  listed  on  the  Sales  File.  Coop  sales  include the apartment number in the address field.
#
#     10. Apartment Number:
#
#     11. Zip Code:  The property’s postal code
#
#     12. Residential Units: The number of residential units at the listed property.
#
#     13. Commercial Units: The number of commercial units at the listed property.
#
#     14. Total Units: The total number of units at the listed property.
#
#     15. Land Square Feet: The land area of the property listed in square feet.
#
#     16. Gross Square Feet: The  total  area  of  all  the  floors  of  a  building  as  measured  from  the  exterior  surfaces  of  the  outside walls of the building, including the land area and space within any building or structure on the property.
#
#     17. Year Built: Year the structure on the property was built.
#
#     18.TAX CLASS AT TIME OF SALE:
#
#     19. Building Class at Time of Sale: The  Building  Classification  is  used  to  describe  a  property’s  constructive  use.  The  first  position  of  the  Building  Class  is  a  letter  that  is  used  to  describe  a  general  class  of  properties  (for  example  “A”  signifies  one-family  homes,  “O”  signifies  office  buildings.  “R”  signifies  condominiums).  The  second  position,  a  number,  adds  more  specific  information  about the property’s use or construction style (using our previous examples “A0” is a Cape Cod  style  one  family  home,  “O4”  is  a  tower  type  office  building  and  “R5”  is  a  commercial  condominium  unit).  The  term  Building  Class  as  used  by  the  Department  of  Finance  is  interchangeable with the term Building Code as used by the Department of Buildings. The link from which the Building classes are defined is
#
# https://www1.nyc.gov/assets/finance/jump/hlpbldgcode.html
#
#     20. Sales Price: Price paid for the property.
#
#     21. Sale Date: Date the property sold
#
#     $0 Sales Price: A  $0  sale  indicates  that  there  was  a  transfer  of  ownership  without  a  cash  consideration.  There  can  be  a  number  of  reasons  for  a  $0  sale  including  transfers  of  ownership  from  parents to children.
#
#
#
# SOME IMPORTANT POINTS ABOUT THE DATA
# 1. Many sales occur with a nonsensically small dollar amount: $0 most commonly. These sales are actually transfers of deeds between parties: for example, parents transferring ownership to their home to a child after moving out for retirement.
# 2. This dataset uses the financial definition of a building/building unit, for tax purposes. In case a single entity owns the building in question, a sale covers the value of the entire building. In case a building is owned piecemeal by its residents (a condominium), a sale refers to a single apartment (or group of apartments) owned by some individual.

# %% [markdown]
# ### Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Loading the dataset

# %%
# loading the dataset
df = pd.read_csv('data/nyc-rolling-sales.csv')
df.shape
# Out:
# (84548, 22)

# %% [markdown]
# The shape of the dataset is (84548,22)
#
#     i.e. The number of rows of the origional dataset is 84548
#     the number of columns is 22

# %%
# looking at the dataset in a dataframe form
df.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %%
# looking at the initial datatypes of columns and information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      84548 non-null  int64
#  1   BOROUGH                         84548 non-null  int64
#  2   NEIGHBORHOOD                    84548 non-null  object
#  3   BUILDING CLASS CATEGORY         84548 non-null  object
#  4   TAX CLASS AT PRESENT            84548 non-null  object
#  5   BLOCK                           84548 non-null  int64
#  6   LOT                             84548 non-null  int64
#  7   EASE-MENT                       84548 non-null  object
#  8   BUILDING CLASS AT PRESENT       84548 non-null  object
#  9   ADDRESS                         84548 non-null  object
#  10  APARTMENT NUMBER                84548 non-null  object
#  11  ZIP CODE                        84548 non-null  int64
# ...

# %% [markdown]
# # Data Cleaning and Exploration

# %%
# changing the column names into lowercase for convenience
df.columns = map(str.lower, df.columns)
df.head()
# Out:
#    unnamed: 0  borough   neighborhood  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        building class category tax class at present  block  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    lot ease-ment building class at present                 address  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %% [markdown]
# #### column: ```borough```
# https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_manhattan.xls
# https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_bronx.xls
# https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_brooklyn.xls
# https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_queens.xls
# https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_statenisland.xls
#
#
# We have converted ```borough``` into category , However the values in this coloumn corresponds to the name of the borough in which the property is located. We can see that in the links above. So we can replace the numbers with corresponding names
#
# 1 - Manhattan
# 2 - Bronx
# 3 - Brooklyn
# 4 - Queens
# 5 - Staten Island

# %%
# replacing borough = 1 to Manhattan
df['borough'][df['borough'] == 1] = 'Manhattan'

# replacing other values 
df['borough'][df['borough'] == 2] = 'Bronx'

df['borough'][df['borough'] == 3] = 'Brooklyn'

df['borough'][df['borough'] == 4] = 'Queens'

df['borough'][df['borough'] == 5] = 'Staten Island'
# Out:
# C:\Users\16476\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head(3)
# Out:
#    unnamed: 0    borough   neighborhood  \
# 0           4  Manhattan  ALPHABET CITY
# 1           5  Manhattan  ALPHABET CITY
# 2           6  Manhattan  ALPHABET CITY
#
#                        building class category tax class at present  block  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
#
#    lot ease-ment building class at present                address  ...  \
# 0    6                                  C2           153 AVENUE B  ...
# 1   26                                  C7  234 EAST 4TH   STREET  ...
# 2   39                                  C7  197 EAST 3RD   STREET  ...
#
#   residential units  commercial units  total units  land square feet  \
# 0                 5                 0            5              1633
# 1                28                 3           31              4616
# ...

# %%
# sanity check
df['borough']
# Out:
# 0            Manhattan
# 1            Manhattan
# 2            Manhattan
# 3            Manhattan
# 4            Manhattan
#              ...
# 84543    Staten Island
# 84544    Staten Island
# 84545    Staten Island
# 84546    Staten Island
# 84547    Staten Island
# Name: borough, Length: 84548, dtype: object

# %% [markdown]
# ### Data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unnamed: 0                      84548 non-null  int64
#  1   borough                         84548 non-null  object
#  2   neighborhood                    84548 non-null  object
#  3   building class category         84548 non-null  object
#  4   tax class at present            84548 non-null  object
#  5   block                           84548 non-null  int64
#  6   lot                             84548 non-null  int64
#  7   ease-ment                       84548 non-null  object
#  8   building class at present       84548 non-null  object
#  9   address                         84548 non-null  object
#  10  apartment number                84548 non-null  object
#  11  zip code                        84548 non-null  int64
# ...

# %% [markdown]
# ### Numeric Variables

# %% [markdown]
# Looking at the dataset at first glance and enquiring about the datatypes we have here,  looks like we need to convert few variables into numeric
#
# For example ```sale price```, ```land square feet```,```gross square feet``` should be numeric type

# %%
#converting the above variables mentioned into numerical variables:
# putting the columns into a list 
numeric_variables = ['sale price','land square feet','gross square feet','year built']

# looping over the numeric_variables
for i in numeric_variables: 
    # coercing errors to NAs that is putting the errors as Nas
    df[i] = pd.to_numeric(df[i], errors='coerce')

# %%
#sanity check
df.dtypes
# Out:
# unnamed: 0                          int64
# borough                            object
# neighborhood                       object
# building class category            object
# tax class at present               object
# block                               int64
# lot                                 int64
# ease-ment                          object
# building class at present          object
# address                            object
# apartment number                   object
# zip code                            int64
# residential units                   int64
# commercial units                    int64
# total units                         int64
# land square feet                  float64
# gross square feet                 float64
# year built                          int64
# tax class at time of sale           int64
# building class at time of sale     object
# sale price                        float64
# sale date                          object
# dtype: object

# %% [markdown]
# The numeric variables are

# %%
df.describe().T
# Out:
#                              count          mean           std  min  \
# unnamed: 0                 84548.0  1.034436e+04  7.151779e+03  4.0
# block                      84548.0  4.237219e+03  3.568263e+03  1.0
# lot                        84548.0  3.762240e+02  6.581368e+02  1.0
# zip code                   84548.0  1.073199e+04  1.290879e+03  0.0
# residential units          84548.0  2.025264e+00  1.672104e+01  0.0
# commercial units           84548.0  1.935587e-01  8.713183e+00  0.0
# total units                84548.0  2.249184e+00  1.897258e+01  0.0
# land square feet           58296.0  3.941676e+03  4.198397e+04  0.0
# gross square feet          56936.0  4.045707e+03  3.503249e+04  0.0
# year built                 84548.0  1.789323e+03  5.373450e+02  0.0
# tax class at time of sale  84548.0  1.657485e+00  8.193412e-01  1.0
# sale price                 69987.0  1.276456e+06  1.140526e+07  0.0
#
#                                  25%       50%        75%           max
# ...

# %% [markdown]
# We can see that a lot of columns has minimum value equal to zero . e.g. ```zip code```, ```residential units```, ```commercial units```, ```total units```, ```land square feet```, ```gross square feet```,```year built```,```sale price```

# %% [markdown]
# To deal with these zero values, we can either convert them into nans and then deal with them or we can deal them individually on column basis.

# %% [markdown]
# ### Non Numeric columns

# %% [markdown]
# Also, few of the variables such as ```borough```, ```neighborhood```,```building class category```,```tax class at present```,```block```,```lot```,```building class at present```,```zip code```,```tax class at the time of sale```,```building class at time of sale``` should be categorical.

# %%
# looking at the count of unique values in each column 
df.nunique()
# Out:
# unnamed: 0                        26736
# borough                               5
# neighborhood                        254
# building class category              47
# tax class at present                 11
# block                             11566
# lot                                2627
# ease-ment                             1
# building class at present           167
# address                           67563
# apartment number                   3989
# zip code                            186
# residential units                   176
# commercial units                     55
# total units                         192
# land square feet                   6061
# gross square feet                  5690
# year built                          158
# tax class at time of sale             4
# building class at time of sale      166
# sale price                        10007
# sale date                           364
# dtype: int64

# %%
# looking at the unique values of the columns 

column_values = df[['borough', 'neighborhood', 'building class category', 'tax class at present','building class at present','zip code','year built','tax class at time of sale','building class at time of sale']].values.ravel()
unique_values =  pd.unique(column_values)
unique_values
# Out:
# array(['Manhattan', 'ALPHABET CITY',
#        '07 RENTALS - WALKUP APARTMENTS             ', '2A', 'C2', 10009,
#        1900, 2, '2', 'C7', '2B', 'C4', 1913, 1920,
#        '08 RENTALS - ELEVATOR APARTMENTS           ', 'D5', 'D9', 'D7',
#        1910, 'D1', 2009, '09 COOPS - WALKUP APARTMENTS               ',
#        'C6', 1925, '2C', 1902, 1928, 1930, 1935, 1937, 1915, 1950, 1929,
#        1901, '10 COOPS - ELEVATOR APARTMENTS             ', 'D0', 1940,
#        'D4', '11A CONDO-RENTALS                           ', 'RR', 2005,
#        ' ', 0, 10002, 1989, '12 CONDOS - WALKUP APARTMENTS              ',
#        'R2', '13 CONDOS - ELEVATOR APARTMENTS            ', 'R4', 2014,
#        2008, 1965, 2013, '14 RENTALS - 4-10 UNIT                     ',
#        'S3', 'S4', 'S5', '15 CONDOS - 2-10 UNIT RESIDENTIAL          ',
#        'R1', 2003, 2006, 2007,
#        '16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT ', 'R8', 1951,
# ...

# %%
column_block = df['block']
unique_values_block =  pd.unique(column_block)
unique_values_block
# Out:
# array([ 392,  399,  402, ..., 6918, 7074, 7092], dtype=int64)

# %%
column_lot = df['lot']
unique_values_lot =  pd.unique(column_lot)
unique_values_lot
# Out:
# array([  6,  26,  39, ..., 655, 423, 679], dtype=int64)

# %% [markdown]
# Here, I'm not going to convert the ```block``` and ```lot``` columns into the categorical one and leave it as numeric as there are about 11566 unique values in this column and same is with column ```lot```, as there are about 2627 unique values.

# %%
# converting the columns mentioned above into the categorical type 
for col in ['borough', 'neighborhood', 'building class category', 'tax class at present','building class at present','zip code','tax class at time of sale','building class at time of sale']:
    df[col] = df[col].astype('category')

# %%
# sanity check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unnamed: 0                      84548 non-null  int64
#  1   borough                         84548 non-null  category
#  2   neighborhood                    84548 non-null  category
#  3   building class category         84548 non-null  category
#  4   tax class at present            84548 non-null  category
#  5   block                           84548 non-null  int64
#  6   lot                             84548 non-null  int64
#  7   ease-ment                       84548 non-null  object
#  8   building class at present       84548 non-null  category
#  9   address                         84548 non-null  object
#  10  apartment number                84548 non-null  object
#  11  zip code                        84548 non-null  category
# ...

# %% [markdown]
# ### ```sale date``` column

# %%
# converting the datatype of the sale date column from object to datetime
df['sale date'] = pd.to_datetime(df['sale date'])

# %%
# sanity check 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unnamed: 0                      84548 non-null  int64
#  1   borough                         84548 non-null  category
#  2   neighborhood                    84548 non-null  category
#  3   building class category         84548 non-null  category
#  4   tax class at present            84548 non-null  category
#  5   block                           84548 non-null  int64
#  6   lot                             84548 non-null  int64
#  7   ease-ment                       84548 non-null  object
#  8   building class at present       84548 non-null  category
#  9   address                         84548 non-null  object
#  10  apartment number                84548 non-null  object
#  11  zip code                        84548 non-null  category
# ...

# %%
# pulling the sale month and sale year out of sale date column
df['sale year'] = pd.DatetimeIndex(df['sale date']).year
df['sale month'] = pd.DatetimeIndex(df['sale date']).month

# %%
#sanity check
df[['sale year','sale month']]
# Out:
#        sale year  sale month
# 0           2017           7
# 1           2016          12
# 2           2016          12
# 3           2016           9
# 4           2016          11
# ...          ...         ...
# 84543       2016          11
# 84544       2017           4
# 84545       2017           7
# 84546       2016          12
# 84547       2016          10
#
# [84548 rows x 2 columns]

# %% [markdown]
# ### Duplicates
# After converting the datatypes to the desired column types lets have a look at the duplicates

# %%
# checking for the duplicates 
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Null Values

# %%
# looking at nulls
df.isna().sum()
# Out:
# unnamed: 0                            0
# borough                               0
# neighborhood                          0
# building class category               0
# tax class at present                  0
# block                                 0
# lot                                   0
# ease-ment                             0
# building class at present             0
# address                               0
# apartment number                      0
# zip code                              0
# residential units                     0
# commercial units                      0
# total units                           0
# land square feet                  26252
# gross square feet                 27612
# year built                            0
# tax class at time of sale             0
# building class at time of sale        0
# sale price                        14561
# sale date                             0
# sale year                             0
# ...

# %%
# looking at the percentage of missing values 
missing_percent  = df.isnull().sum() * 100 / len(df)
missing_percent
# Out:
# unnamed: 0                         0.000000
# borough                            0.000000
# neighborhood                       0.000000
# building class category            0.000000
# tax class at present               0.000000
# block                              0.000000
# lot                                0.000000
# ease-ment                          0.000000
# building class at present          0.000000
# address                            0.000000
# apartment number                   0.000000
# zip code                           0.000000
# residential units                  0.000000
# commercial units                   0.000000
# total units                        0.000000
# land square feet                  31.049818
# gross square feet                 32.658372
# year built                         0.000000
# tax class at time of sale          0.000000
# building class at time of sale     0.000000
# sale price                        17.222170
# ...

# %% [markdown]
# There are some of the values which are blank in the dataset. Let's check them and replace them with Nan values

# %%
# repalcing the blank values with Nan
df.replace(' ',np.nan, inplace=True)

df.head()
# Out:
#    unnamed: 0    borough   neighborhood  \
# 0           4  Manhattan  ALPHABET CITY
# 1           5  Manhattan  ALPHABET CITY
# 2           6  Manhattan  ALPHABET CITY
# 3           7  Manhattan  ALPHABET CITY
# 4           8  Manhattan  ALPHABET CITY
#
#                        building class category tax class at present  block  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    lot  ease-ment building class at present                 address  ...  \
# 0    6        NaN                        C2            153 AVENUE B  ...
# 1   26        NaN                        C7   234 EAST 4TH   STREET  ...
# ...

# %%
df.isna().sum()
# Out:
# unnamed: 0                            0
# borough                               0
# neighborhood                          0
# building class category               0
# tax class at present                738
# block                                 0
# lot                                   0
# ease-ment                         84548
# building class at present           738
# address                               0
# apartment number                  65496
# zip code                              0
# residential units                     0
# commercial units                      0
# total units                           0
# land square feet                  26252
# gross square feet                 27612
# year built                            0
# tax class at time of sale             0
# building class at time of sale        0
# sale price                        14561
# sale date                             0
# sale year                             0
# ...

# %%
df.isna().sum() /len(df) *100
# Out:
# unnamed: 0                          0.000000
# borough                             0.000000
# neighborhood                        0.000000
# building class category             0.000000
# tax class at present                0.872877
# block                               0.000000
# lot                                 0.000000
# ease-ment                         100.000000
# building class at present           0.872877
# address                             0.000000
# apartment number                   77.466055
# zip code                            0.000000
# residential units                   0.000000
# commercial units                    0.000000
# total units                         0.000000
# land square feet                   31.049818
# gross square feet                  32.658372
# year built                          0.000000
# tax class at time of sale           0.000000
# building class at time of sale      0.000000
# sale price                         17.222170
# ...

# %%
#At first glance, we can see that the columns ``` tax class at present``` and ```building class at present``` 
#have same percentage of missing values. 
#Lets see if the missing values in both the columns are at same location
x = df.loc[df['tax class at present'].isnull()]
y = df.loc[df['building class at present'].isnull()]

# %%
# checking if the missing values in both the columns are at same index
x.index == y.index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
# Dropping the nulls in column ``` tax class at present```
df.dropna(subset = ['tax class at present'], inplace=True)

# %%
df.isna().sum()
# Out:
# unnamed: 0                            0
# borough                               0
# neighborhood                          0
# building class category               0
# tax class at present                  0
# block                                 0
# lot                                   0
# ease-ment                         83810
# building class at present             0
# address                               0
# apartment number                  64758
# zip code                              0
# residential units                     0
# commercial units                      0
# total units                           0
# land square feet                  25866
# gross square feet                 27226
# year built                            0
# tax class at time of sale             0
# building class at time of sale        0
# sale price                        14496
# sale date                             0
# sale year                             0
# ...

# %% [markdown]
# #### 1. Dropping the columns ```unnamed: 0``` ,```ease-ment``` and ```apartment number```

# %% [markdown]
# The reason behind deleting these columns is that the column unnamed: 0 is just analogous to index, easement has 100% of missing values and similar situation with apartment having almost 77% of missing values.

# %%
# dropping the columns 
df = df.drop(['unnamed: 0','ease-ment','apartment number'], axis=1)

# %%
df.duplicated().sum()
# Out:
# 765

# %%
# dropping the duplicate values 
df.drop_duplicates(inplace = True)

# %%
# sanity check
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 2. Dealing with null values

# %%
# check this before running 

'''At first glance, we can see that the columns ``` tax class at present``` and ```building class at present``` 
have same percentage of missing values. 
Lets see if the missing values in both the columns are at same location
x = df.loc[df['tax class at present'].isnull()]
y = df.loc[df['building class at present'].isnull()]
# checking if the missing values in both the columns are at same index
x.index == y.index
# Dropping the nulls in column ``` tax class at present```
#df1 = df.dropna(subset = ['tax class at present'], inplace=True)
# keeping only those rows which has residential units + commercial units equal to total units 
df1 = df1[df1['residential units'] + df1['commercial units'] == df1['total units']]
df1
'''
# Out:
# "At first glance, we can see that the columns ``` tax class at present``` and ```building class at present``` \nhave same percentage of missing values. \nLets see if the missing values in both the columns are at same location\nx = df.loc[df['tax class at present'].isnull()]\ny = df.loc[df['building class at present'].isnull()]\n# checking if the missing values in both the columns are at same index\nx.index == y.index\n# Dropping the nulls in column ``` tax class at present```\n#df1 = df.dropna(subset = ['tax class at present'], inplace=True)\n# keeping only those rows which has residential units + commercial units equal to total units \ndf1 = df1[df1['residential units'] + df1['commercial units'] == df1['total units']]\ndf1\n"

# %%
df.isna().sum() /len(df) *100
# Out:
# borough                            0.000000
# neighborhood                       0.000000
# building class category            0.000000
# tax class at present               0.000000
# block                              0.000000
# lot                                0.000000
# building class at present          0.000000
# address                            0.000000
# zip code                           0.000000
# residential units                  0.000000
# commercial units                   0.000000
# total units                        0.000000
# land square feet                  30.908544
# gross square feet                 32.511289
# year built                         0.000000
# tax class at time of sale          0.000000
# building class at time of sale     0.000000
# sale price                        16.991992
# sale date                          0.000000
# sale year                          0.000000
# sale month                         0.000000
# dtype: float64

# %% [markdown]
# Lets make a new dataframe df2 by dropping all null values and check the correlation between different variables

# %%
# dropping the nulls
df2 = df.dropna()

# %%
df2.isna().sum()
# Out:
# borough                           0
# neighborhood                      0
# building class category           0
# tax class at present              0
# block                             0
# lot                               0
# building class at present         0
# address                           0
# zip code                          0
# residential units                 0
# commercial units                  0
# total units                       0
# land square feet                  0
# gross square feet                 0
# year built                        0
# tax class at time of sale         0
# building class at time of sale    0
# sale price                        0
# sale date                         0
# sale year                         0
# sale month                        0
# dtype: int64

# %%
df2.corr()
# Out:
#                       block       lot  residential units  commercial units  \
# block              1.000000 -0.140806          -0.042362         -0.003564
# lot               -0.140806  1.000000          -0.033256         -0.008083
# residential units -0.042362 -0.033256           1.000000          0.013314
# commercial units  -0.003564 -0.008083           0.013314          1.000000
# total units       -0.037676 -0.030332           0.847419          0.542109
# land square feet   0.002972 -0.034178           0.416091          0.048605
# gross square feet -0.044478 -0.041887           0.627542          0.062808
# year built         0.088891 -0.366134           0.024258          0.004789
# sale price        -0.051585 -0.014358           0.125498          0.045697
# sale year         -0.005532  0.002397          -0.011453         -0.007717
# sale month         0.011536 -0.002268           0.014953          0.004622
#
# ...

# %% [markdown]
# We can see that the columns ```land square feet``` and ```gross square feet``` are the ones with high correaltion with ```residential units``` , So we could have used this variable to fill Nan values in ```land square feet```,```gross square feet``` and ```sale price``` by the following the method.
#
# This method of dealing with the nan values in ```land square feet```, ```gross square feet``` and ```sale price``` could be filling the nan values with accordance with the ```residential units``` columns. I will try to find the mean value for each of these columns using group by function on the ```residential units``` column.
#
#  Then These values are put into dictionary and then filled in the corresponding columns using mean values.

# %%
# sanity check after filling the null values 
df.isna().sum()
# Out:
# borough                               0
# neighborhood                          0
# building class category               0
# tax class at present                  0
# block                                 0
# lot                                   0
# building class at present             0
# address                               0
# zip code                              0
# residential units                     0
# commercial units                      0
# total units                           0
# land square feet                  25668
# gross square feet                 26999
# year built                            0
# tax class at time of sale             0
# building class at time of sale        0
# sale price                        14111
# sale date                             0
# sale year                             0
# sale month                            0
# dtype: int64

# %%
# dropping the null values left for the convenience
df = df.dropna()
df.isna().sum()
# Out:
# borough                           0
# neighborhood                      0
# building class category           0
# tax class at present              0
# block                             0
# lot                               0
# building class at present         0
# address                           0
# zip code                          0
# residential units                 0
# commercial units                  0
# total units                       0
# land square feet                  0
# gross square feet                 0
# year built                        0
# tax class at time of sale         0
# building class at time of sale    0
# sale price                        0
# sale date                         0
# sale year                         0
# sale month                        0
# dtype: int64

# %%
# shape of the dataset after dealing with the nulls 
df.shape
# Out:
# (47544, 21)

# %%
# checking if both the columns 'building class at present' and 'building class at time of sale' have same values 
df[df.loc[:,'building class at present'].values == df.loc[:,'building class at time of sale']]
# Out:
#              borough   neighborhood  \
# 0          Manhattan  ALPHABET CITY
# 3          Manhattan  ALPHABET CITY
# 4          Manhattan  ALPHABET CITY
# 6          Manhattan  ALPHABET CITY
# 9          Manhattan  ALPHABET CITY
# ...              ...            ...
# 84543  Staten Island        WOODROW
# 84544  Staten Island        WOODROW
# 84545  Staten Island        WOODROW
# 84546  Staten Island        WOODROW
# 84547  Staten Island        WOODROW
#
#                            building class category tax class at present  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# 6      07 RENTALS - WALKUP APARTMENTS                                2B
# 9      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# ...

# %% [markdown]
#  We can see that this is not the case , as the shape of our dataset without nulls is (83018, 21) and for the above condition the shape is 82800 rows × 21 columns

# %% [markdown]
# ### Target Variable ```sale price```

# %%
df.describe().T
# Out:
#                      count          mean           std     min        25%  \
# block              47544.0  4.993789e+03  3.431769e+03     1.0    2218.00
# lot                47544.0  2.278511e+02  4.906937e+02     1.0      21.00
# residential units  47544.0  2.553656e+00  1.723198e+01     0.0       1.00
# commercial units   47544.0  2.392310e-01  1.088558e+01     0.0       0.00
# total units        47544.0  2.811985e+00  2.050190e+01     0.0       1.00
# land square feet   47544.0  3.295120e+03  3.066143e+04     0.0    1462.75
# gross square feet  47544.0  3.551979e+03  2.931144e+04     0.0     876.00
# year built         47544.0  1.841982e+03  4.371478e+02     0.0    1920.00
# sale price         47544.0  1.160690e+06  1.349207e+07     0.0  100000.00
# sale year          47544.0  2.016644e+03  4.787591e-01  2016.0    2016.00
# sale month         47544.0  6.590127e+00  3.488798e+00     1.0       4.00
#
#                         50%        75%           max
# ...

# %% [markdown]
# Looking at the above table
#
#     1. We can see that in the columns ```land square feet```, ```gross square feet``` and ```sale price```, The minimum value is 0, which is very ambigous.
#     2. The 0 values for  ```land square feet``` and  ```gross square feet``` means that the property doesnt even exist.
#     3. We have to deal with these values either drop them or replace them with appropriate values.
#     4. The 0 value for the ```sale price``` has a special meaning i.e. A '0'  sale  indicates  that  there  was  a  transfer  of  ownership  without  a  cash  consideration.  There  can  be  a  number  of  reasons  for  a  $0  sale  including  transfers  of  ownership  from  parents to children. This was mentioned in the glossary of the data.
#     5. We have to either drop these values or we can also fill them with appropriate values.
#     6. 75% of properties have no commercial units and 50% of the properties have only 1 unit.
#     7. The ```year built``` column has also 0 values.

# %% [markdown]
# ### Dealing with the  '0' values in columns

# %% [markdown]
# #### 1. Target Variable ```Sale Price```

# %%
# checking the top 10 properties in terms of the sale price
df.nlargest(10,'sale price')
# Out:
#          borough           neighborhood  \
# 7447   Manhattan            MIDTOWN CBD
# 2559   Manhattan              FINANCIAL
# 2557   Manhattan              FINANCIAL
# 6332   Manhattan               KIPS BAY
# 2050   Manhattan                FASHION
# 35389   Brooklyn  DOWNTOWN-FULTON FERRY
# 6317   Manhattan          JAVITS CENTER
# 9594   Manhattan           MIDTOWN WEST
# 66508     Queens       LONG ISLAND CITY
# 2090   Manhattan              FINANCIAL
#
#                            building class category tax class at present  \
# 7447   21 OFFICE BUILDINGS                                            4
# 2559   21 OFFICE BUILDINGS                                            4
# 2557   21 OFFICE BUILDINGS                                            4
# 6332   08 RENTALS - ELEVATOR APARTMENTS                               2
# 2050   21 OFFICE BUILDINGS                                            4
# 35389  29 COMMERCIAL GARAGES                                          4
# ...

# %%
# to check the outliers in the sale price column 
plt.figure(figsize=(8,6))
plt.scatter(range(df.shape[0]), np.sort(df['sale price'].values))
plt.xlabel('index', fontsize=12)
plt.ylabel('sale price', fontsize=12)
plt.show()

# %% [markdown]
# Looking at above plot and pulling out the top 10 properties by their sale price, looks like the properties with 2 billion sale price are outliers, however studying it in more detail come across that this property is genuine https://en.wikipedia.org/wiki/245_Park_Avenue. We can also see that few properties have sale price = 0 USD, the reason of which was also explained in the Glossary that these are the properties with their ownership transferred from  parents to children.
#
#
# Also I have decided to keep the rows which have sale price greater than USD 50000 and less than USD 500,000,000.
# The reason behind keeping only these values is that sale price less than USD 50,000 either could be replaced or dropped.
# Similarly, there are only few values in sale price column which is greater than 500,000,000 USD .e.g.The most expensive property in the origional dataset is around 2 Billion USD. These few values will act as outliers and can affect the models employed on the data and could alter the results i.e. predictions made on the target variable.

# %%
df.shape
# Out:
# (47544, 21)

# %%
# keeping only the properties with sale price greater than 10000 USD
df= df[(df['sale price']>50000) & (df['sale price']<500000000)].copy()

# %%
# looking at the distribution of sale price
import seaborn as sns
plt.figure(figsize=(8,6))
sns.distplot(np.log(df['sale price'].values), kde=True)
plt.xlabel('price', fontsize=12)
plt.show()

# %%
# keeping the track of the shape of the dataset
df.shape
# Out:
# (36106, 21)

# %% [markdown]
# #### Dealing with zero values in column ```land square feet```

# %%
# keeping only those rows which has land square feet != 0
df = df[df['land square feet']!=0].copy()

# %%
df.shape
# Out:
# (28483, 21)

# %% [markdown]
# #### Dealing with zero values in column ```gross square feet```

# %%
# Checking the number of zero rows left in "gross square feet" column
df[df['gross square feet']==0]
# Out:
#         borough     neighborhood                      building class category  \
# 18364     Bronx         BATHGATE  29 COMMERCIAL GARAGES
# 18371     Bronx         BATHGATE  31 COMMERCIAL VACANT LAND
# 18373     Bronx         BATHGATE  41 TAX CLASS 4 - OTHER
# 18756     Bronx       BAYCHESTER  05 TAX CLASS 1 VACANT LAND
# 18760     Bronx       BAYCHESTER  05 TAX CLASS 1 VACANT LAND
# ...         ...              ...                                          ...
# 49207  Brooklyn  WINDSOR TERRACE  05 TAX CLASS 1 VACANT LAND
# 49346  Brooklyn  WYCKOFF HEIGHTS  05 TAX CLASS 1 VACANT LAND
# 49347  Brooklyn  WYCKOFF HEIGHTS  06 TAX CLASS 1 - OTHER
# 49397  Brooklyn  WYCKOFF HEIGHTS  41 TAX CLASS 4 - OTHER
# 49400  Brooklyn  WYCKOFF HEIGHTS  41 TAX CLASS 4 - OTHER
#
#       tax class at present  block  lot building class at present  \
# 18364                    4   2918   29                        G7
# 18371                    4   3028   13                        V9
# ...

# %% [markdown]
# There are 424 rows still left in the ```gross square land``` column which are zero. These should be equal to ```land square feet``` column values. Because of the definition of these columns that we have seen in the glossary of the dataset,
#
#     Land Square Feet: The land area of the property listed in square feet.
#
#     Gross Square Feet: The  total  area  of  all  the  floors  of  a  building  as  measured  from  the  exterior  surfaces  of  the  outside walls of the building, including the land area and space within any building or structure on the property.
#
# So I will fill these values with the values in land square feet column.

# %%
# replacing the rows which have 0 value in gross square feet with corresponding land square feet.
# considering they have no additional structures on the land and exterior surfaces
df.loc[df['gross square feet'] == 0, 'gross square feet'] = df['land square feet']

# %%
# sanity check
df[df['gross square feet'] == 0].values
# Out:
# array([], shape=(0, 21), dtype=object)

# %%
df.describe().T
# Out:
#                      count          mean           std      min       25%  \
# block              28483.0  5.548004e+03  3.759813e+03      5.0    2706.0
# lot                28483.0  6.235200e+01  1.293652e+02      1.0      19.0
# residential units  28483.0  2.953516e+00  1.928935e+01      0.0       1.0
# commercial units   28483.0  3.086051e-01  1.398046e+01      0.0       0.0
# total units        28483.0  3.260682e+00  2.395431e+01      0.0       1.0
# land square feet   28483.0  4.185175e+03  3.684676e+04    200.0    2000.0
# gross square feet  28483.0  4.178885e+03  2.954454e+04    120.0    1362.0
# year built         28483.0  1.915612e+03  2.212470e+02      0.0    1920.0
# sale price         28483.0  1.547973e+06  7.335679e+06  51000.0  440000.0
# sale year          28483.0  2.016647e+03  4.780028e-01   2016.0    2016.0
# sale month         28483.0  6.595829e+00  3.472378e+00      1.0       4.0
#
#                         50%       75%          max
# ...

# %% [markdown]
# #### ```Total units```

# %% [markdown]
# I am keeping only those properties which have total units = residential units + commercial units

# %%
# keeping only those rows which has residential units + commercial units equal to total units 
df = df[df['residential units'] + df['commercial units'] == df['total units']].copy()

# %%
# keeping only non-zero rows 
df = df[df['total units']>0]

# %%
# keeping track of shape of the dataset
df.shape
# Out:
# (28049, 21)

# %% [markdown]
# #### ```year built```

# %% [markdown]
# The column ```year built``` also has 0 values , So I decided to keep only those properties that were built after 1650, as when i tried to search for the oldest property in NYC , it comes out to be built in 1652, https://ny.curbed.com/maps/nyc-oldest-buildings-houses-map

# %%
df = df[df['year built']>1650]

# %%
# checking shape
df.shape
# Out:
# (28040, 21)

# %% [markdown]
# #### ```zip code```

# %%
# checking for any zero values in "zip code" column
df[df['zip code']== 0]
# Out:
#              borough              neighborhood  \
# 20408          Bronx               HUNTS POINT
# 23508          Bronx  SCHUYLERVILLE/PELHAM BAY
# 32862       Brooklyn                  CANARSIE
# 55497         Queens              FAR ROCKAWAY
# 58844         Queens            FLUSHING-NORTH
# 63257         Queens              HOWARD BEACH
# 71466         Queens                  ROSEDALE
# 76296  Staten Island                  ANNADALE
# 76301  Staten Island                  ANNADALE
#
#                            building class category tax class at present  \
# 20408  29 COMMERCIAL GARAGES                                          4
# 23508  02 TWO FAMILY DWELLINGS                                        1
# 32862  22 STORE BUILDINGS                                             4
# 55497  01 ONE FAMILY DWELLINGS                                        1
# 58844  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
# ...

# %% [markdown]
# I have googled the Zip Codes of the various preoperties by their address and filled the zip codes accordingly.
# We can also find the zip codes in this link https://www.apartmentfinder.com/New-York/New-York/New-York-Apartments-By-Zip-Code
#
#
#
# 1. 2 RIVER TERRACE, 1-2 RIVER TERRACE,1 RIVER TERRACE has  10282 as ```zip code```
# 2. WHITTIER STREET -               10474
# 3. 3405 BRUCKNER BOULEVARD -       10461
# 4. 94-09 AVENUE L -                11428
# 5. SHEPHERD AVENUE -               11208
# 6. 1103 BEACH 25 STREET -          11691
# 7. 35-56 159TH STREET -            11358
# 8. 69-49B PARK DRIVE EAST -        11367
# 9. 102-15 DUNTON COURT -           11414
# 10. 146-81 SPRINGFIELD LANE -      11413
# 11. SERENA COURT -                 10312
# 12. RICHMOND ROAD -                10302
# 13. SHEPHERD AVENUE-               11208
# We can fill these values

# %%
# Replacing the zero values in the "zip code" column with their corresponding zip codes.

df.loc[(df['zip code'] == 0) & (df['address'] == 'WHITTIER STREET'), 'zip code'] = 10474
df.loc[(df['zip code'] == 0) & (df['address'] == '3405 BRUCKNER BOULEVARD'), 'zip code'] = 10461
df.loc[(df['zip code'] == 0) & (df['address'] == '94-09 AVENUE L'), 'zip code'] = 11428
df.loc[(df['zip code'] == 0) & (df['address'] == '1103 BEACH 25 STREET'), 'zip code'] = 11691
df.loc[(df['zip code'] == 0) & (df['address'] == '35-56 159TH STREET'), 'zip code'] = 11358
df.loc[(df['zip code'] == 0) & (df['address'] == '69-49B PARK DRIVE EAST'), 'zip code'] = 11367
df.loc[(df['zip code'] == 0) & (df['address'] == '102-15 DUNTON COURT'), 'zip code'] = 11414
df.loc[(df['zip code'] == 0) & (df['address'] == '146-81 SPRINGFIELD LANE'), 'zip code'] = 11413
df.loc[(df['zip code'] == 0) & (df['address'] == '2 RIVER TERRACE'), 'zip code'] = 10282
df.loc[(df['zip code'] == 0) & (df['address'] == '1-2 RIVER TERRACE'), 'zip code'] = 10282
df.loc[(df['zip code'] == 0) & (df['address'] == '1 RIVER TERRACE'), 'zip code'] = 10282
df.loc[(df['zip code'] == 0) & (df['address'] == 'RICHMOND ROAD'), 'zip code'] = 10302
df.loc[(df['zip code'] == 0) & (df['address'] == 'SHEPHERD AVENUE'), 'zip code'] = 11208
df.loc[(df['zip code'] == 0) & (df['address'] == 'SERENA COURT'), 'zip code'] = 10312

# %% [markdown]
# May be , the filling of Zip Code at this point doesn't bring any potential outcome here , but as a part of data cleaning process , to demonstrate and keeping the maximum possible data, I have filled the zero values of Zip code.

# %%
#SANITY CHECK
# checking for any zero values in "zip code" column
df[df['zip code']== 0]
# Out:
# Empty DataFrame
# Columns: [borough, neighborhood, building class category, tax class at present, block, lot, building class at present, address, zip code, residential units, commercial units, total units, land square feet, gross square feet, year built, tax class at time of sale, building class at time of sale, sale price, sale date, sale year, sale month]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.head()
# Out:
#      borough   neighborhood                      building class category  \
# 0  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 9  Manhattan  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
#
#   tax class at present  block  lot building class at present  \
# 0                   2A    392    6                        C2
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
# 6                   2B    406   32                        C4
# 9                    2    387  153                        D9
#
#                   address zip code  residential units  ...  total units  \
# 0            153 AVENUE B    10009                  5  ...            5
# 3     154 EAST 7TH STREET    10009                 10  ...           10
# ...

# %%
# resetting the index
df.reset_index(drop = True)
# Out:
#              borough   neighborhood  \
# 0          Manhattan  ALPHABET CITY
# 1          Manhattan  ALPHABET CITY
# 2          Manhattan  ALPHABET CITY
# 3          Manhattan  ALPHABET CITY
# 4          Manhattan  ALPHABET CITY
# ...              ...            ...
# 28035  Staten Island        WOODROW
# 28036  Staten Island        WOODROW
# 28037  Staten Island        WOODROW
# 28038  Staten Island        WOODROW
# 28039  Staten Island        WOODROW
#
#                            building class category tax class at present  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                2B
# 2      07 RENTALS - WALKUP APARTMENTS                                2A
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# ...

# %%
df.describe().T
# Out:
#                      count          mean           std      min       25%  \
# block              28040.0  5.572809e+03  3.772477e+03      5.0    2724.0
# lot                28040.0  6.175966e+01  1.179773e+02      1.0      19.0
# residential units  28040.0  2.992796e+00  1.942569e+01      0.0       1.0
# commercial units   28040.0  3.120185e-01  1.409015e+01      0.0       0.0
# total units        28040.0  3.304815e+00  2.412978e+01      1.0       1.0
# land square feet   28040.0  4.025522e+03  3.239593e+04    200.0    2000.0
# gross square feet  28040.0  4.111344e+03  2.959022e+04    120.0    1360.0
# year built         28040.0  1.940683e+03  3.048084e+01   1800.0    1920.0
# sale price         28040.0  1.523575e+06  7.012244e+06  51000.0  442500.0
# sale year          28040.0  2.016646e+03  4.781287e-01   2016.0    2016.0
# sale month         28040.0  6.597183e+00  3.472016e+00      1.0       4.0
#
#                         50%       75%          max
# ...

# %%
# creating a new column as "age of building" at the time of sale 
df['age of building'] = (df['year built'] - df['sale year']).abs()

# %%
df.head()
# Out:
#      borough   neighborhood                      building class category  \
# 0  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 9  Manhattan  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
#
#   tax class at present  block  lot building class at present  \
# 0                   2A    392    6                        C2
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
# 6                   2B    406   32                        C4
# 9                    2    387  153                        D9
#
#                   address zip code  residential units  ...  land square feet  \
# 0            153 AVENUE B    10009                  5  ...            1633.0
# ...

# %%
df.reset_index(inplace = True)

# %%
df.shape
# Out:
# (28040, 23)

# %%
df['tax class at present'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        2A
# 1        2B
# 2        2A
# 3        2B
# 4         2
#          ..
# 28035     1
# 28036     1
# 28037     1
# 28038     4
# 28039     4
# Name: tax class at present, Length: 28040, dtype: category
# Categories (10, object): [1, 1A, 1B, 1C, ..., 2B, 2C, 3, 4]>

# %%
# keeping only digits in the tax class at present 
df['tax class at present 2'] = df['tax class at present'].astype(str).str[:1]

# %%
df['tax class at present 2']
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 28035    1
# 28036    1
# 28037    1
# 28038    4
# 28039    4
# Name: tax class at present 2, Length: 28040, dtype: object

# %%
df = df.drop('tax class at present', axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28040 entries, 0 to 28039
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   index                           28040 non-null  int64
#  1   borough                         28040 non-null  category
#  2   neighborhood                    28040 non-null  category
#  3   building class category         28040 non-null  category
#  4   block                           28040 non-null  int64
#  5   lot                             28040 non-null  int64
#  6   building class at present       28040 non-null  category
#  7   address                         28040 non-null  object
#  8   zip code                        28040 non-null  category
#  9   residential units               28040 non-null  int64
#  10  commercial units                28040 non-null  int64
#  11  total units                     28040 non-null  int64
# ...

# %% [markdown]
# I am going to save this clean dataset as a csv and we can then use this to do data visualisation and modelling process and we need not reload the whole notebook everytime and it is very easy to load this saved csv in a new notebook as well so make things more easy and less complicated.

# %%
#saving the clean dataset in a csv.
df.to_csv(r'C:\Users\16476\Desktop\Capstone_final\nyc_clean_dataset1.csv', index = False)

# %% [markdown]
# In the whole data cleaning process, I have deleted 3 columns and created 3 new columns.

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# #### 1. Plotting the pair plot for ```sale price``` on different columns

# %%
#Plotting PairPlot for sale price on different columns 
plt.figure()
#sns.set(font_scale=2.5)
pair = sns.pairplot(df, vars=['sale price', 'residential units','commercial units','total units',
                              'gross square feet', 'land square feet'], height=5, aspect=1.2)
plt.show()

# %% [markdown]
# #### 2. Top 5 most expensive properties

# %%
# Top 5 most expensive properties 
df.sort_values('sale price', ascending=False).head(5).T
# Out:
#                                                                       497    \
# index                                                                  6317
# borough                                                           Manhattan
# neighborhood                                                  JAVITS CENTER
# building class category         21 OFFICE BUILDINGS
# block                                                                   732
# lot                                                                      36
# building class at present                                                O3
# address                                                433-447 NINTH AVENUE
# zip code                                                              10001
# residential units                                                         0
# commercial units                                                          2
# total units                                                               2
# ...

# %% [markdown]
# #### 3. Average Sale Price of the NYC properties in the different Boroughs

# %%
# looking at the average sale price of the properties in different boroughs 
x1= df['sale price'].groupby(df['borough']).mean()
print(x1)

# putting it in a dataframe and sorting the values
df_avg =df[['borough', 'sale price']].groupby(by='borough').mean().sort_values(by='sale price', ascending=True)


# resetting the index
df_avg.reset_index(inplace = True)
df_avg
# Out:
# borough
# Bronx            1.069168e+06
# Brooklyn         1.584661e+06
# Manhattan        1.495136e+07
# Queens           9.389589e+05
# Staten Island    5.443268e+05
# Name: sale price, dtype: float64
#          borough    sale price
# 0  Staten Island  5.443268e+05
# 1         Queens  9.389589e+05
# 2          Bronx  1.069168e+06
# 3       Brooklyn  1.584661e+06
# 4      Manhattan  1.495136e+07

# %%
# plotting the bar graph of average price of properties in each borough
#plt.figure(figsize=(10,8))
sns.barplot(y = 'borough', x = 'sale price', data = df_avg)
plt.title('Average sale price of properties in each borough')
plt.xlabel('Sale Price in USD')
plt.ylabel('Borough')
#plt.show()
# Out:
# Text(0, 0.5, 'Borough')

# %% [markdown]
# We could see that the average price in all the Boroughs is quite same except Manhattan. The average price for Manhattan is way to high making it a very very expensive place to live. Check out this article that validate our finding as well.  https://www.investopedia.com/articles/personal-finance/012315/how-expensive-new-york-city-really.asp#:~:text=How%20Expensive%20Is%20it%20to,according%20to%20a%20Kiplinger%20survey.

# %% [markdown]
# #### 4. comparison of the sale price of properties with the age of the building

# %%
df['age of building'].nunique()
# Out:
# 139

# %%
df['age of building'].describe()
# Out:
# count    28040.000000
# mean        75.963053
# std         30.488984
# min          0.000000
# 25%         57.000000
# 50%         86.000000
# 75%         97.000000
# max        217.000000
# Name: age of building, dtype: float64

# %%
plt.figure()
sns.lineplot(x = 'age of building', y = 'sale price', data = df)
plt.title('Effect of the age of the building on the sale price')
plt.show()

# %% [markdown]
# We can see that the building which are on avergae 90 to 100 years old have a very high average price.

# %%
# looking at the distribution of the column year built
sns.distplot(df['year built'], bins=20)
plt.show()

# %%
# looking at the distribution of the column sale price
plt.figure(figsize=(10,6))
sns.distplot(df['sale price'], kde=True)
plt.xlabel('sale price', fontsize = 12)
plt.ylabel('frequency', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('distribution of the sale price values', fontsize = 12)
plt.show()

# %%
# taking log of the column sale price

plt.figure(figsize=(10,6))
sns.distplot(np.log(df['sale price'].values), kde=True)
plt.xlabel('sale price', fontsize = 12)
plt.ylabel('frequency', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('distribution of the sale price values', fontsize = 12)
plt.show()

# %%
# looking at the distribution of the column "land square feet"

plt.figure(figsize=(10,6))
sns.distplot(df['land square feet'], kde=True)
plt.xlabel('land square feet', fontsize = 12)
plt.ylabel('frequency', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('distribution of the land square feet values', fontsize = 12)
plt.show()

# %%
# looking at the distribution of the column "land square feet" using log transformation
plt.figure(figsize=(10,6))
sns.distplot(np.log(df['land square feet'].values), kde=True)
plt.xlabel('gross square feet', fontsize = 12)
plt.ylabel('frequency', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('distribution of the gross square feet values', fontsize = 12)
plt.show()

# %%
# looking at the distribution of the column "gross square feet" 
plt.figure(figsize=(10,6))
sns.distplot(df['gross square feet'], kde=True)
plt.xlabel('gross square feet', fontsize = 12)
plt.ylabel('frequency', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('distribution of the gross square feet values', fontsize = 12)
plt.show()

# %%
# looking at the distribution of the column "gross square feet" using log transformation
plt.figure(figsize=(10,6))
sns.distplot(np.log(df['gross square feet'].values), kde=True)
plt.xlabel('gross square feet', fontsize = 12)
plt.ylabel('frequency', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('distribution of the gross square feet values', fontsize = 12)
plt.show()

# %%
# looking at the distribution of the column "residential units" 
plt.figure(figsize=(10,6))
sns.distplot(df['residential units'], kde=True)
plt.xlabel('residential units', fontsize = 12)
plt.ylabel('frequency', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('distribution of the residential units values', fontsize = 12)
plt.show()

# %%
# looking at the distribution of the column "residential units" 
plt.figure(figsize=(10,6))
sns.distplot(np.log(df['residential units'].values + 1), kde=True)
plt.xlabel('residential units', fontsize = 12)
plt.ylabel('frequency', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('distribution of the residential units values', fontsize = 12)
plt.show()

# %%
# looking at the distribution of the column "total units" 
plt.figure(figsize=(10,6))
sns.distplot(df['total units'])
plt.xlabel('toatl units', fontsize = 12)
plt.ylabel('frequency', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('distribution of the total units values', fontsize = 12)
plt.show()

# %%
# looking at the distribution of the column "total units" 
plt.figure(figsize=(10,6))
sns.distplot(np.log(df['total units']))
plt.xlabel('toatl units', fontsize = 12)
plt.ylabel('frequency', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('distribution of the total units values', fontsize = 12)
plt.show()

# %% [markdown]
# We have seen that log transformations on the columns like ```land square feet```, ```gross square feet```, ```total units``` and ```sale price``` has transformed the columns and the plots have shown that these transformations have transformed the distribution into more normal distribution than the origional.

# %% [markdown]
# #### The building category which makes the most of the market share

# %%
# looking at the category of building which makes most of the market share in terms of selling 
df['building class category'].value_counts()
# Out:
# 01 ONE FAMILY DWELLINGS                         12500
# 02 TWO FAMILY DWELLINGS                          9641
# 03 THREE FAMILY DWELLINGS                        2275
# 07 RENTALS - WALKUP APARTMENTS                   1714
# 22 STORE BUILDINGS                                467
# 14 RENTALS - 4-10 UNIT                            315
# 21 OFFICE BUILDINGS                               207
# 08 RENTALS - ELEVATOR APARTMENTS                  196
# 29 COMMERCIAL GARAGES                             166
# 30 WAREHOUSES                                     162
# 27 FACTORIES                                      102
# 37 RELIGIOUS FACILITIES                            50
# 26 OTHER HOTELS                                    40
# 10 COOPS - ELEVATOR APARTMENTS                     28
# 32 HOSPITAL AND HEALTH FACILITIES                  27
# 05 TAX CLASS 1 VACANT LAND                         24
# 33 EDUCATIONAL FACILITIES                          24
# ...

# %%
# putting the top 10 building class categories with most market share in terms of sale price in a dataframe
df_building = df[['sale price']].groupby(df['building class category']).sum().sort_values(by = 'sale price', ascending = False).head(10)
df_building.reset_index(inplace = True)
df_building
# Out:
#                        building class category    sale price
# 0  01 ONE FAMILY DWELLINGS                      8.459427e+09
# 1  02 TWO FAMILY DWELLINGS                      7.874187e+09
# 2  07 RENTALS - WALKUP APARTMENTS               5.994324e+09
# 3  08 RENTALS - ELEVATOR APARTMENTS             4.286757e+09
# 4  21 OFFICE BUILDINGS                          4.177041e+09
# 5  03 THREE FAMILY DWELLINGS                    2.333671e+09
# 6  22 STORE BUILDINGS                           1.944891e+09
# 7  26 OTHER HOTELS                              1.358926e+09
# 8  25 LUXURY HOTELS                             1.139020e+09
# 9  30 WAREHOUSES                                9.067085e+08

# %%
# using above dataframe to plot and visualise it 
plt.figure(figsize = (10,8))
plt.barh('building class category', 'sale price',data = df_building)
plt.xlabel('sale price in USD')
plt.ylabel('building class category')
plt.title('building class categories and their market share in terms of sale price')
plt.show()

# %% [markdown]
# The below visualisations are made to use in presenation and is just a repitition of above visualisation. We can clearly see that one family dwellings and two family dwellings make the most of market share in terms of sale price. These two are followed by walkup and elevator apartments.

# %%
# putting the top 5 building class categories with most market share in terms of sale price in a dataframe
df_building = df[['sale price']].groupby(df['building class category']).sum().sort_values(by = 'sale price', ascending = False).head(5)
df_building.reset_index(inplace = True)
df_building
# Out:
#                        building class category    sale price
# 0  01 ONE FAMILY DWELLINGS                      8.459427e+09
# 1  02 TWO FAMILY DWELLINGS                      7.874187e+09
# 2  07 RENTALS - WALKUP APARTMENTS               5.994324e+09
# 3  08 RENTALS - ELEVATOR APARTMENTS             4.286757e+09
# 4  21 OFFICE BUILDINGS                          4.177041e+09

# %%
# using above dataframe to plot and visualise it 
plt.figure(figsize = (5,3))
plt.barh('building class category','sale price',data = df_building)
plt.xlabel('sale price in USD')
plt.ylabel('building class category')
plt.title('building class categories and their market share in terms of sale price')
plt.show()

# %%
# Calculating which borough registers the maximum sales in 2016 and 2017
plt.figure(figsize = (10,8))
sns.barplot(x='sale year', y='sale price', hue='borough', data=df, palette='rocket', ci=None)
plt.title('Sales per Borough for year 2016 and 2017')
plt.show()

# %% [markdown]
# # Feature Selection and Statistical Modelling

# %% [markdown]
# Feature Selection is the process where you automatically or manually select those features which contribute most to your prediction variable or output in which you are interested in.
#
# Having irrelevant features in your data can decrease the accuracy of the models and make your model learn based on irrelevant features.
#
#     Benefits of performing feature selection before modeling your data
#
#     · Reduces Overfitting: Less redundant data means less opportunity to make decisions based on noise.
#
#     · Improves Accuracy: Less misleading data means modeling accuracy improves.
#
#     · Reduces Training Time: fewer data points reduce algorithm complexity and algorithms train faster.
#
# Source of above text : https://towardsdatascience.com/feature-selection-techniques-in-machine-learning-with-python-f24e7da3f36e

# %% [markdown]
# We want to keep the variables or features which are highly correlated to our target variable ```sale price```, So we will perform the feature selection and for that we can use methods like Anova Test, Chi squared test, Correlation matrix and heatmap
#
# These methods will help us to select the best subset out of set of all independent features.

# %% [markdown]
# #### Univariate Selection

# %% [markdown]
# The scikit learn library has SelectKBest class that can be used to select specific number of features.

# %%
numeric_variables = df[['block','lot','residential units','commercial units','total units','land square feet','gross square feet','year built','sale month','sale year','age of building']]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

#independent columns
X = df[['block','lot','residential units','commercial units','total units','land square feet','gross square feet','year built','sale month','sale year','age of building']]

#target column 
y = df['sale price']

# %%
#apply SelectKBest class to extract top 5 best features

# Instantiate 
best_features = SelectKBest(score_func=chi2, k=5)
#fit
best_fmodel = best_features.fit(X,y)
# calculate the scores and put it in a dataframe
b_scores = pd.DataFrame(best_fmodel.scores_)
b_columns = pd.DataFrame(X.columns)

# %%
# concatanating the scores and columns into a single dataframe
feature_scores = pd.concat([b_columns,b_scores],axis=1)

#naming the dataframe columns
feature_scores.columns = ['Features','Score']  
feature_scores
# Out:
#              Features         Score
# 0               block  1.940868e+07
# 1                 lot  1.383178e+06
# 2   residential units  1.868060e+06
# 3    commercial units  1.732726e+06
# 4         total units  1.889268e+06
# 5    land square feet  2.699309e+09
# 6   gross square feet  2.106520e+09
# 7          year built  3.714991e+03
# 8          sale month  8.819007e+03
# 9           sale year  5.491240e-01
# 10    age of building  9.494553e+04

# %%
# sorting the values 
feature_scores.sort_values('Score', ascending = False)
df_f = feature_scores.sort_values('Score', ascending = False)
df_f.reset_index(inplace = True)
df_f
# Out:
#     index           Features         Score
# 0       5   land square feet  2.699309e+09
# 1       6  gross square feet  2.106520e+09
# 2       0              block  1.940868e+07
# 3       4        total units  1.889268e+06
# 4       2  residential units  1.868060e+06
# 5       3   commercial units  1.732726e+06
# 6       1                lot  1.383178e+06
# 7      10    age of building  9.494553e+04
# 8       8         sale month  8.819007e+03
# 9       7         year built  3.714991e+03
# 10      9          sale year  5.491240e-01

# %%
df_f.drop('index', axis =1 )
# Out:
#              Features         Score
# 0    land square feet  2.699309e+09
# 1   gross square feet  2.106520e+09
# 2               block  1.940868e+07
# 3         total units  1.889268e+06
# 4   residential units  1.868060e+06
# 5    commercial units  1.732726e+06
# 6                 lot  1.383178e+06
# 7     age of building  9.494553e+04
# 8          sale month  8.819007e+03
# 9          year built  3.714991e+03
# 10          sale year  5.491240e-01

# %% [markdown]
# We have left the categorical variables ```block``` and ```lot``` as numerical, as the reason was explained earlier as there are a lot of unique values in both the variables.
#
# Looking at the above scores, we can see that the columns ```land square feet``` and ```gross square feet``` are the columns with highest score which tells us that these variables are most predictive for the target variable.

# %% [markdown]
# #### Correlation matrix

# %%
df.corr()
# Out:
#                       index     block       lot  residential units  \
# index              1.000000  0.242332  0.031046          -0.091215
# block              0.242332  1.000000  0.042006          -0.055755
# lot                0.031046  0.042006  1.000000          -0.010366
# residential units -0.091215 -0.055755 -0.010366           1.000000
# commercial units  -0.008695 -0.004690 -0.003851           0.011611
# total units       -0.078510 -0.047624 -0.010594           0.811831
# land square feet   0.010208 -0.005904  0.010272           0.556351
# gross square feet -0.077968 -0.057268 -0.007110           0.813189
# year built         0.317270  0.065608  0.106714          -0.004928
# sale price        -0.166915 -0.131252 -0.013139           0.219376
# sale year         -0.007007  0.004222 -0.004064          -0.014094
# sale month         0.000349  0.007849  0.005064           0.017772
# age of building   -0.317295 -0.065524 -0.106749           0.004706
#
# ...

# %%
# To visualise the correlation better 
sns.heatmap(df.corr(),vmin=-1, vmax=1);
sns.heatmap;
plt.subplots(figsize=(15,8))
sns.heatmap(df.corr(),vmin=-1, vmax=1)

# %% [markdown]
# #### Interpretation of correlation between two variables
#   1. Positive Correlation: both variables change in the same direction.
#   2. Neutral Correlation: No relationship in the change of the variables.
#   3. Negative Correlation: variables change in opposite directions.
#
#   Reference from the notebook
#  1. A good intuition for a correlation coefficient is 'The degree of variation in one dimension that is explained by the other variable'. Correlation coefficient is not the slope of the line:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/d4/Correlation_examples2.svg">

# %% [markdown]
# Visualising the scatter plot of columns 'block','lot','residential units','commercial units','total units','land square feet','gross square feet','year built','sale month','sale year' and 'age of building' with the target variable ```sale price```

# %%
ncolumns = ['block','lot','residential units',
            'commercial units','total units','land square feet',
            'gross square feet','year built','sale month','sale year','age of building']

for col in ncolumns:
    
    print('COLUMN:', col)
    # Visualize the values
    plt.figure()
    plt.scatter(x= col ,y='sale price',data= df)
    plt.ylabel('sale price')
    plt.xlabel(f'{col}')
    plt.show()
    
    print('\n')
# Out:
# COLUMN: block
# COLUMN: lot
# COLUMN: residential units
# COLUMN: commercial units
# COLUMN: total units
# COLUMN: land square feet
# COLUMN: gross square feet
# COLUMN: year built
# COLUMN: sale month
# COLUMN: sale year
# COLUMN: age of building

# %% [markdown]
# ### Linear Regression Assumptions
#
# These are few assumptions that we make before fitting the model
#
# 1. There is a linear relationship between the dependent and independent variables
# 2. The independent variables are independent of each other (no multicollinearity)
# 3. Residuals are normally distributed
# 4. Homoscedasticity: Variance of error terms are similar across the values of the independent variables
#
#
# The first two are usually checked before the model is fit, while the last two are checked after the model is fit. This is a process that's called performing model diagnostics.
#
# ### Linear Model Diagnostics
#
# Before fitting the model, we are checking
# 1. the linear relationship between the dependent and indepepndent variables.
# This is done by making the scatter plots between every independent variable and dependent variable.
#
# checking the correlation between the each indpendent and dependent variable
# 2. The independent variables are independent of each other( i.e. there is no multicollinearity)
# This is done by checking correlation between all independent variables.
#
#
# * Homoscedasticity: Variance of error terms are similar across the values of the independent variables
#     * Look at a plot of the residuals vs fitted values. It should look like random noise.

# %%
# making a copy of the origional dataframe 
# so that we can perform changes and do iterations
df_lin = df.copy()

# %%
# doing the log transformation on the variables 
df_lin['land square feet'] = np.log(df_lin['land square feet'])
df_lin['gross square feet'] = np.log(df_lin['gross square feet'])
df_lin['sale price'] = np.log(df_lin['sale price'])
df_lin['total units'] = df_lin['total units'] + 1 
df_lin['residential units'] = df_lin['residential units'] + 1 
df_lin['commercial units'] = df_lin['commercial units'] + 1 
df_lin['age of building'] = df_lin['age of building'] +1 
df_lin['total units'] = np.log2(df_lin['total units'])
df_lin['residential units'] = np.log(df_lin['residential units'])
df_lin['commercial units'] = np.log(df_lin['commercial units'])
df_lin['age of building'] = np.log(df_lin['age of building'])

# %% [markdown]
# #### 1. Iteration 1
# Keeping all numerical variables which have more relative importance as compared to other variables.
# Here I'm not including "block" and "lot" as they were the categorical variables , however this could tried in next iteration.

# %%
# lets declare our independent and dependent varaibles 

# declaring X 
X = df_lin[['land square feet','gross square feet','total units','residential units','commercial units','age of building']]
y= df_lin['sale price']

# %%
# using a loop to make plots 
for col in X.columns: 
    plt.figure()
    plt.scatter(X[col],y)
    plt.ylabel('sale price')
    plt.xlabel(col)
    plt.show();

# %% [markdown]
# We can see that although the relation between these columns in X with sale price is not very linearly sharp,but we will proceed with these varibles to fit the model

# %%
# importing the statsmodel library
import statsmodels.api as sm

# adding constant to X
X_withconstant = sm.add_constant(X)

# %%
# modelling 
# 1. Instantiate model
lin_model1 = sm.OLS(y, X_withconstant)

# 2. Fit model
lin_model1_results = lin_model1.fit()

lin_model1_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sale price   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.457
# Method:                 Least Squares   F-statistic:                     3928.
# Date:                Sat, 27 Jun 2020   Prob (F-statistic):               0.00
# Time:                        20:08:02   Log-Likelihood:                -27314.
# No. Observations:               28040   AIC:                         5.464e+04
# Df Residuals:                   28033   BIC:                         5.470e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# How to interpret this result?
# To do this first we will write an equation
#
# $$ y = 7.3867 + (-0.0258) x_1 + 0.7804 x_2 + (-0.0053) x_3 + (-0.0292) x_4 + 0.2605 x_5 + 0.0840 x_6 $$
#
#
# 1. Here the value of interecpt is 7.3867
#
# Keeping all other variables constant
# 2. With one unit increase in land square feet , there is 0.0258 decrease in sale price.
# 3. With one unit increase in gross square feet , there is 0.7804 increaes in sale price.
# 4. With one unit increase in total units, there is 0.0053 decrease in sale price.
# 5. With one unit increase in residential units, there is 0.0292 decrease in sale price.
# 6. With one unit increase in commercial units, there is 0.2605 increase in sale price.
# 7. With one unti increase in age of building , there is 0.0840 increase in sale price.

# %% [markdown]
# *After fitting model*
# * Residuals are normally distributed
#     * Look at a histogram of the residuals, do they look normally distributed?
#
# * Homoscedasticity: Variance of error terms are similar across the values of the independent variables
#     * Look at a plot of the residuals vs fitted values. It should look like random noise.

# %% [markdown]
# Evaluating the model

# %%
# looking at the parameters 
print(lin_model1_results.params)

# residuals 
lin_model1_resids = lin_model1_results.resid 
lin_model1_resids.head()
# Out:
# const                7.386653
# land square feet    -0.025847
# gross square feet    0.780431
# total units         -0.005273
# residential units   -0.029193
# commercial units     0.260484
# age of building      0.084006
# dtype: float64
# 0    1.331505
# 1    0.810578
# 2    1.796152
# 3    0.963512
# 4    1.498245
# dtype: float64

# %%
# fitted values 

lin_model1_fittedvals = lin_model1_results.fittedvalues 
lin_model1_fittedvals.head()
# Out:
# 0    14.374856
# 1    14.375167
# 2    14.098800
# 3    14.012909
# 4    15.104251
# dtype: float64

# %%
#looking at the scatter plot of fitted values and residuals of the model 
plt.figure()
plt.scatter(lin_model1_fittedvals,lin_model1_resids)
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# This above plot should be a bunch of scattered dots. Although it looks scattered but there is some sort of cluster forming, So this means the model is having some multicollinearity issues. We can make it better to fit the model by removing this multicollinarity. Lets review it again by adding and removing columns. This is an iterative process. Apart from that R^2 value is 0.457 which indicates the proportion of the variability in the dependent variable.
#
# If your regression model contains independent variables that are statistically significant, a reasonably high R-squared value makes sense. The statistical significance indicates that changes in the independent variables correlate with shifts in the dependent variable.

# %% [markdown]
# #### 2. Iteration 2
# In the previous iteration , the p-value for the ```total units``` column is greater than 0.5, so lets try backward elimination method and try to remove this column and run the model.

# %%
# adding more columns 
# declaring X and y 
X = df_lin[['land square feet','gross square feet','residential units','commercial units','age of building']]
y= df_lin['sale price']

# %%
# adding constant to X
X_withconstant = sm.add_constant(X)

# modelling 
# 1. Instantiate model
lin_model1 = sm.OLS(y, X_withconstant)

# 2. Fit model
lin_model1_results = lin_model1.fit()

lin_model1_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sale price   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.457
# Method:                 Least Squares   F-statistic:                     4714.
# Date:                Sat, 27 Jun 2020   Prob (F-statistic):               0.00
# Time:                        20:08:24   Log-Likelihood:                -27314.
# No. Observations:               28040   AIC:                         5.464e+04
# Df Residuals:                   28034   BIC:                         5.469e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# The R-squared value is still the same as compared to first iteration as adding columns haven't affected anything much.
#
# R-squared values ranges from zero to one, with zero indicating that the proposed model does not improve prediction over the mean model, and one indicating perfect prediction. Improvement in the regression model results in proportional increases in R-squared.

# %% [markdown]
# #### 3. Iteration 3

# %%
# trying with a single column

X = df_lin['gross square feet']
y = df_lin['sale price']

# %%
# adding constant 
X_withconstant = sm.add_constant(X)
import statsmodels.api as sm
# modelling 
# 1. Instantiate model
lin_model1 = sm.OLS(y, X_withconstant)

# 2. Fit model
lin_model1_results = lin_model1.fit()

lin_model1_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sale price   R-squared:                       0.443
# Model:                            OLS   Adj. R-squared:                  0.443
# Method:                 Least Squares   F-statistic:                 2.229e+04
# Date:                Sat, 27 Jun 2020   Prob (F-statistic):               0.00
# Time:                        20:08:28   Log-Likelihood:                -27665.
# No. Observations:               28040   AIC:                         5.533e+04
# Df Residuals:                   28038   BIC:                         5.535e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# This iteration has decreased our R- squared value to 0.443.

# %% [markdown]
# ### Train- Test Split and Scaling the data

# %%
# lets declare our independent and dependent varaibles 

# declaring X 
X = df_lin[['land square feet','gross square feet','total units','residential units','commercial units','age of building']]
y= df_lin['sale price']

# %%
# doing the train test split into 70 percent as training data and 30 percent as test data 
# Split the data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# scale the data
from sklearn.preprocessing import StandardScaler
# instantiate 
scaler = StandardScaler()
# fit 
scaler.fit(X_train)
#transform
X_scaled_train = scaler.transform(X_train)
X_scaled_test = scaler.transform(X_test)

# %%
# adding constant to X
X_withconstant = sm.add_constant(X_scaled_train)

# modelling 
lin_model1 = sm.OLS(y_train, X_withconstant)

lin_model1_results = lin_model1.fit()

lin_model1_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sale price   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.457
# Method:                 Least Squares   F-statistic:                     2754.
# Date:                Sat, 27 Jun 2020   Prob (F-statistic):               0.00
# Time:                        20:08:36   Log-Likelihood:                -19052.
# No. Observations:               19628   AIC:                         3.812e+04
# Df Residuals:                   19621   BIC:                         3.817e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.4829      0.005   2956.886      0.000      13.474      13.492
# ...

# %% [markdown]
# We can see that scaling hasn't changed anything in terms of the R-squared value that we have. This iteration is same as first iteration.
#
# However the coefficients have changed and p value for x4 i.e. for the residential units is greater than 0.5

# %% [markdown]
# # Linear regression
# using SK Learn

# %%
# %%time
# import the libraries
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# Instantiate the model
regressor = LinearRegression()
# fit the model
regressor.fit(X_scaled_train, y_train)

# predicting the test result
y_pred_LR = regressor.predict(X_scaled_test)
# Out:
# Wall time: 16.9 ms

# %%
# calculating the r2 score 
score= r2_score(y_test,y_pred_LR)
print(f'r-squared score for Linear Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = mean_absolute_error(y_test, y_pred_LR)
print(f'mean absolute error for Linear regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = mean_squared_error(y_test, y_pred_LR)
print(f'mean squared error for Linear regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_LR).abs())/y_test)*100).mean()
print(f' mean percentage error for Linear Regressor is {mean_per_error}')
# Out:
# r-squared score for Linear Regressor is 0.45533289832145396
# mean absolute error for Linear regressor is 0.4546766153249667
# mean squared error for Linear regressor is 0.41769190495739644
#  mean percentage error for Linear Regressor is 3.371985270944759

# %%
# putting the values in dataframe
# predicted_SP = Predicted values of sale price
# test_SP = Actual Sale Price values from the data
# percentage error
per_error = (((y_test - y_pred_LR).abs())/y_test)*100
# putting these in dataframe
df_error = pd.DataFrame({'test_SP': y_test,'Predicted_SP': y_pred_LR, 'Percentage error': per_error})
df_error.reset_index(inplace = True)

# %%
df_error = df_error.drop('index', axis = 1)
df_error
# Out:
#         test_SP  Predicted_SP  Percentage error
# 0     13.647092     13.537350          0.804145
# 1     13.644129     13.259284          2.820590
# 2     13.521139     13.905789          2.844803
# 3     12.013701     13.439481         11.867951
# 4     13.710150     13.535660          1.272706
# ...         ...           ...               ...
# 8407  13.102161     13.312457          1.605054
# 8408  12.847663     12.959150          0.867757
# 8409  13.664688     12.826661          6.132789
# 8410  13.049793     13.357349          2.356790
# 8411  13.017003     13.192527          1.348423
#
# [8412 rows x 3 columns]

# %% [markdown]
# ## Random Forest Regressor

# %%
# %%time
# import the library
from sklearn.ensemble import RandomForestRegressor

# Instantiate 
RF_Regressor = RandomForestRegressor(criterion='mse')

# Fit the regressor
RF_Regressor.fit(X_scaled_train, y_train)

# Predict
y_pred_RF = RF_Regressor.predict(X_scaled_test)
# Out:
# Wall time: 13.6 s

# %%
# calculating the r2 score 
score= r2_score(y_test,y_pred_RF)
print(f'r-squared score for Random Forest Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred_RF).abs()).sum())/y_pred_RF.shape
print(f'mean absolute error for Random Forest regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred_RF).abs())**2).sum())/y_pred_RF.shape
print(f'mean squared error for Random Forest regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_RF).abs())/y_test)*100).mean()
print(f' mean percentage error for Random Forest Regressor is {mean_per_error}')
# Out:
# r-squared score for Random Forest Regressor is 0.496652690060717
# mean absolute error for Random Forest regressor is [0.42962922]
# mean squared error for Random Forest regressor is [0.38600477]
#  mean percentage error for Random Forest Regressor is 3.1943622342457423

# %%
# absolute error
abs_error = (y_test - y_pred_RF).abs()
# percentage error
per_error = (((y_test - y_pred_RF).abs())/y_test)*100
# putting these in dataframe
df_error_RF = pd.DataFrame({'test_SP': y_test,'Predicted_SP': y_pred_RF, 'Absolute Error': abs_error,'Percentage error': per_error})
df_error_RF.reset_index(inplace = True)

# %%
df_error_RF = df_error_RF.drop('index', axis = 1)
df_error_RF
# Out:
#         test_SP  Predicted_SP  Absolute Error  Percentage error
# 0     13.647092     13.283346        0.363746          2.665375
# 1     13.644129     12.467080        1.177049          8.626778
# 2     13.521139     13.605590        0.084450          0.624581
# 3     12.013701     13.343386        1.329685         11.068071
# 4     13.710150     13.508585        0.201565          1.470187
# ...         ...           ...             ...               ...
# 8407  13.102161     13.334627        0.232467          1.774262
# 8408  12.847663     13.269548        0.421885          3.283749
# 8409  13.664688     12.790499        0.874189          6.397431
# 8410  13.049793     13.196653        0.146860          1.125382
# 8411  13.017003     13.014461        0.002542          0.019527
#
# [8412 rows x 4 columns]

# %%
# chaecking the max percentage error by sorting the values in descending order
df_error_RF.sort_values('Percentage error', ascending = False)
# Out:
#         test_SP  Predicted_SP  Absolute Error  Percentage error
# 6942  11.195540     18.072872    6.877333e+00      6.142922e+01
# 5641  11.179814     17.772252    6.592438e+00      5.896734e+01
# 6242  11.177453     16.085438    4.907986e+00      4.390970e+01
# 379   12.301383     17.285846    4.984463e+00      4.051954e+01
# 1541  11.191342     15.573972    4.382631e+00      3.916090e+01
# ...         ...           ...             ...               ...
# 2469  12.947214     12.947214    2.309264e-14      1.783599e-13
# 2597  12.947214     12.947214    2.309264e-14      1.783599e-13
# 4582  12.947214     12.947214    2.309264e-14      1.783599e-13
# 3677  12.947214     12.947214    2.309264e-14      1.783599e-13
# 6633  12.947214     12.947214    2.309264e-14      1.783599e-13
#
# [8412 rows x 4 columns]

# %% [markdown]
# # Decision Tree Regressor

# %%
# %%time
# importing the library
from sklearn.tree import DecisionTreeRegressor

# Instantiate the model
DT_Regressor = DecisionTreeRegressor(random_state=0)

# Fit the regressor
DT_Regressor.fit(X_scaled_train, y_train)

# Predict
y_pred_DT = DT_Regressor.predict(X_scaled_test)
# Out:
# Wall time: 136 ms

# %%
# calculating the r2 score 
score= r2_score(y_test,y_pred_DT)
print(f'r-squared score for Decision Tree Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred_DT).abs()).sum())/y_pred_DT.shape
print(f'mean absolute error for Decision Tree regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred_DT).abs())**2).sum())/y_pred_DT.shape
print(f'mean squared error for Decision Tree regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_DT).abs())/y_test)*100).mean()
print(f' mean percentage error for Random Forest Regressor is {mean_per_error}')
# Out:
# r-squared score for Decision Tree Regressor is 0.07102949667305969
# mean absolute error for Decision Tree regressor is [0.58008572]
# mean squared error for Decision Tree regressor is [0.7124048]
#  mean percentage error for Random Forest Regressor is 4.29472702208794

# %%
# percentage error
per_error = (((y_test - y_pred_DT).abs())/y_test)*100
# putting these in dataframe
df_error_DT = pd.DataFrame({'test_SP': y_test,'Predicted_SP': y_pred_DT, 'Percentage error': per_error})
df_error_DT.reset_index(inplace = True)

# %%
df_error_DT = df_error_DT.drop('index', axis = 1)
df_error_DT
# Out:
#         test_SP  Predicted_SP  Percentage error
# 0     13.647092     12.762827          6.479510
# 1     13.644129     12.611538          7.568026
# 2     13.521139     14.346139          6.101552
# 3     12.013701     13.081541          8.888524
# 4     13.710150     13.120361          4.301840
# ...         ...           ...               ...
# 8407  13.102161     13.450947          2.662055
# 8408  12.847663     13.651814          6.259124
# 8409  13.664688     12.611538          7.707091
# 8410  13.049793     13.262125          1.627096
# 8411  13.017003     13.028053          0.084888
#
# [8412 rows x 3 columns]

# %%
# chaecking the max percentage error by sorting the values in descending order
df_error_DT.sort_values('Percentage error', ascending = False)
# Out:
#         test_SP  Predicted_SP  Percentage error
# 6942  11.195540     19.021667         69.903969
# 5641  11.179814     18.643824         66.763284
# 6924  11.801032     17.312018         46.699182
# 379   12.301383     18.035018         46.609682
# 1237  19.130415     11.233899         41.277283
# ...         ...           ...               ...
# 3727  13.151922     13.151922          0.000000
# 3777  15.444751     15.444751          0.000000
# 4816  13.527828     13.527828          0.000000
# 3810  13.217674     13.217674          0.000000
# 5612  14.077875     14.077875          0.000000
#
# [8412 rows x 3 columns]

# %% [markdown]
# # Ridge Regression

# %%
# %%time
# importing the library for Ridge 
from sklearn.linear_model import Ridge

# Instantiate the model
ridge = Ridge(alpha = 1)

# Fit the regressor
ridge.fit(X_scaled_train, y_train)

# Predict
y_pred = ridge.predict(X_scaled_test)

# calculating the r2 score 
score= r2_score(y_test,y_pred)
print(f'r-squared score for Ridge Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred).abs()).sum())/y_pred.shape
print(f'mean absolute error for Ridge Regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred).abs())**2).sum())/y_pred.shape
print(f'mean squared error for Ridge Regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred).abs())/y_test)*100).mean()
print(f' mean percentage error for Ridge Regressor is {mean_per_error}')
# Out:
# r-squared score for Ridge Regressor is 0.4553356873497246
# mean absolute error for Ridge Regressor is [0.45467387]
# mean squared error for Ridge Regressor is [0.41768977]
#  mean percentage error for Ridge Regressor is 3.371961297899339
# Wall time: 22.4 ms

# %% [markdown]
# #### Using Grid Search

# %%
# %%time
# importing the library for Ridge 
from sklearn.linear_model import Ridge
# importing grid search 
from sklearn.model_selection import GridSearchCV
# importing the cross validation 
from sklearn.model_selection import cross_val_score

# declaring the parameters 
parameters={'alpha':np.arange(-100,210,10)}
# Instantiate the model and GS
Ridge_Regressor=Ridge()
Ridge_RegressorGS=GridSearchCV(Ridge_Regressor,parameters,scoring='neg_mean_squared_error',cv=5)
# Fit the model
Ridge_RegressorGS.fit(X_scaled_train,y_train)


# finding the best parameter
print(f'Best Parameter for the Ridge Regressor Model {Ridge_RegressorGS.best_params_}')
print(f'Best Score for the Ridge Regressor Model is {Ridge_RegressorGS.best_score_}')
# Out:
# Best Parameter for the Ridge Regressor Model {'alpha': 120}
# Best Score for the Ridge Regressor Model is -0.40898048291476546
# Wall time: 749 ms

# %%
# making predictions 
y_pred_ridge = Ridge_RegressorGS.predict(X_scaled_test)
# calculating the r2 score 
score= r2_score(y_test,y_pred)
print(f'r-squared score for Ridge Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred_ridge).abs()).sum())/y_pred_ridge.shape
print(f'mean absolute error for Ridge Regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred_ridge).abs())**2).sum())/y_pred_ridge.shape
print(f'mean squared error for Ridge Regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_ridge).abs())/y_test)*100).mean()
print(f' mean percentage error for Ridge Regressor is {mean_per_error}')
# Out:
# r-squared score for Ridge Regressor is 0.4553356873497246
# mean absolute error for Ridge Regressor is [0.45439191]
# mean squared error for Ridge Regressor is [0.41751433]
#  mean percentage error for Ridge Regressor is 3.36942657124153

# %% [markdown]
# # Lasso Regression

# %%
# %%time
# importing the library for Ridge 
from sklearn.linear_model import Lasso

# Instantiate the model
lasso = Lasso(alpha = 1)

# Fit the regressor
lasso.fit(X_scaled_train, y_train)

# Predict
y_pred = lasso.predict(X_scaled_test)

# calculating the r2 score 
score= r2_score(y_test,y_pred)
print(f'r-squared score for Lasso Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred).abs()).sum())/y_pred.shape
print(f'mean absolute error for Lasso Regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred).abs())**2).sum())/y_pred.shape
print(f'mean squared error for Lasso Regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred).abs())/y_test)*100).mean()
print(f' mean percentage error for Lasso Regressor is {mean_per_error}')
# Out:
# r-squared score for Lasso Regressor is -9.115774834200785e-05
# mean absolute error for Lasso Regressor is [0.60364366]
# mean squared error for Lasso Regressor is [0.7669455]
#  mean percentage error for Lasso Regressor is 4.386181862622661
# Wall time: 14.5 ms

# %% [markdown]
# #### using Grid Search

# %%
# %%time
# importing the Library
from sklearn.linear_model import Lasso

# declaring the parameters 
parameters={'alpha':np.arange(-100,210,10)}
# Instantiate the model and GS
Lasso_Regressor=Lasso()
Lasso_RegressorGS=GridSearchCV(Lasso_Regressor,parameters,scoring='neg_mean_squared_error',cv=5)
# Fit the model
Lasso_RegressorGS.fit(X_scaled_train,y_train)


# finding the best parameter
print(f'Best Parameter for the Lasso Regressor Model {Lasso_RegressorGS.best_params_}')
print(f'Best Score for the Lasso Regressor Model is {Lasso_RegressorGS.best_score_}')
# Out:
# C:\Users\16476\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\16476\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\16476\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3214.8161849027874, tolerance: 1.1796790676312385
#   positive)
# C:\Users\16476\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# ...

# %%
# making predictions 
y_pred_lasso = Lasso_RegressorGS.predict(X_scaled_test)
# calculating the r2 score 
score= r2_score(y_test,y_pred_lasso)
print(f'r-squared score for Lasso Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred_lasso).abs()).sum())/y_pred_lasso.shape
print(f'mean absolute error for Lasso Regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred_lasso).abs())**2).sum())/y_pred_lasso.shape
print(f'mean squared error for Lasso Regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_lasso).abs())/y_test)*100).mean()
print(f' mean percentage error for Lasso Regressor is {mean_per_error}')
# Out:
# r-squared score for Lasso Regressor is 0.45533289832145396
# mean absolute error for Lasso Regressor is [0.45467662]
# mean squared error for Lasso Regressor is [0.4176919]
#  mean percentage error for Lasso Regressor is 3.371985270944759

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(3, 2, figsize=(20, 18), sharex=True)
# Plots for Predicted and Test Values 
# Plot for Linear Regression 
sns.distplot(y_test-y_pred_LR, color="b", ax=axes[0, 0])

# Decision Tree Regressor 
sns.distplot(y_test-y_pred_DT, color="r", ax=axes[0, 1])

# Random Forest Regressor 
sns.distplot(y_test-y_pred_RF, color="g", ax=axes[1, 0])

# Ridge Regression 
sns.distplot(y_test-y_pred_ridge, color="m", ax=axes[1, 1])

# Lasso Regression 
sns.distplot(y_test-y_pred_lasso, color="m", ax=axes[2, 0])

# %%
df_error_com = pd.DataFrame({'test_SP':y_test,'pred_SP_LR': y_pred_LR,'pred_SP_RF': y_pred_RF,'pred_SP_DT': y_pred_DT,'y_pred_lasso': y_pred_lasso,'y_pred_ridge': y_pred_ridge})
df_error_com
# Out:
#          test_SP  pred_SP_LR  pred_SP_RF  pred_SP_DT  y_pred_lasso  \
# 17754  13.647092   13.537350   13.283346   12.762827     13.537350
# 23099  13.644129   13.259284   12.467080   12.611538     13.259284
# 6921   13.521139   13.905789   13.605590   14.346139     13.905789
# 4341   12.013701   13.439481   13.343386   13.081541     13.439481
# 26491  13.710150   13.535660   13.508585   13.120361     13.535660
# ...          ...         ...         ...         ...           ...
# 9480   13.102161   13.312457   13.334627   13.450947     13.312457
# 21853  12.847663   12.959150   13.269548   13.651814     12.959150
# 20573  13.664688   12.826661   12.790499   12.611538     12.826661
# 20338  13.049793   13.357349   13.196653   13.262125     13.357349
# 17601  13.017003   13.192527   13.014461   13.028053     13.192527
#
#        y_pred_ridge
# 17754     13.533046
# 23099     13.263115
# 6921      13.901399
# 4341      13.439110
# 26491     13.537537
# ...             ...
# ...

# %%
df_error_com.reset_index(inplace = True )

# %%
df_error_com
# Out:
#       index    test_SP  pred_SP_LR  pred_SP_RF  pred_SP_DT  y_pred_lasso  \
# 0     17754  13.647092   13.537350   13.283346   12.762827     13.537350
# 1     23099  13.644129   13.259284   12.467080   12.611538     13.259284
# 2      6921  13.521139   13.905789   13.605590   14.346139     13.905789
# 3      4341  12.013701   13.439481   13.343386   13.081541     13.439481
# 4     26491  13.710150   13.535660   13.508585   13.120361     13.535660
# ...     ...        ...         ...         ...         ...           ...
# 8407   9480  13.102161   13.312457   13.334627   13.450947     13.312457
# 8408  21853  12.847663   12.959150   13.269548   13.651814     12.959150
# 8409  20573  13.664688   12.826661   12.790499   12.611538     12.826661
# 8410  20338  13.049793   13.357349   13.196653   13.262125     13.357349
# 8411  17601  13.017003   13.192527   13.014461   13.028053     13.192527
#
#       y_pred_ridge
# 0        13.533046
# 1        13.263115
# 2        13.901399
# ...

# %% [markdown]
# This above dataframe, df_error_com compares the predicted sale price values by the linear regression, random forest , decision tree, lasso and ridge regression ( both with cross validation) against the test sale price.We can see that the Random forest regressor is giving us the least amount of error as compared to all other models.

# %% [markdown]
# Let us try to adjust the number of trees with n_estimators in Random Forest and see if it affects our model in any way.

# %% [markdown]
# ## Hyperparameter optimization using Grid Search
# #### adjusting the n_estimators and max_depth in Random Forest Model

# %% [markdown]
# #### n_estimators in the range of 1 to 202 and max_depth = 1

# %%
# Making a parameter_grid
n_estimators = np.arange(1, 202, 20)
param_grid = {'n_estimators': n_estimators}

# Make the base estimator
rf = RandomForestRegressor(max_depth = 1)

# Make my GridSearchCV
my_gridsearchcv = GridSearchCV(estimator = rf, param_grid=param_grid, n_jobs=-1)

# %%
# %%time
# Fitting on training set 
my_gridsearchcv.fit(X_scaled_train, y_train)
# Out:
# Wall time: 13.8 s
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=1,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
# ...

# %%
# best estimator
my_gridsearchcv.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=1, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=201, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
# Plot out the CV accuracies
cv_scores = my_gridsearchcv.cv_results_['mean_test_score']

pd.DataFrame({'n_estimators':n_estimators, 'test_scores':cv_scores})
# Out:
#     n_estimators  test_scores
# 0              1     0.313341
# 1             21     0.342971
# 2             41     0.343409
# 3             61     0.343582
# 4             81     0.345607
# 5            101     0.344809
# 6            121     0.345177
# 7            141     0.346054
# 8            161     0.345306
# 9            181     0.345728
# 10           201     0.346586

# %%
plt.figure()
plt.plot(n_estimators, cv_scores, marker='o')
plt.xlabel('n_estimators')
plt.ylabel('Accuracy')
plt.show()

# %%
# making predictions 
y_pred_rf = my_gridsearchcv.predict(X_scaled_test)

# %%
# calculating the r2 score 
score= r2_score(y_test,y_pred_rf)

# %%
score
# Out:
# 0.3500599885317036

# %%
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred_rf).abs()).sum())/y_pred_rf.shape
print(f'mean absolute error for Random Forest Regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred_rf).abs())**2).sum())/y_pred_rf.shape
print(f'mean squared error for Random Forest Regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_rf).abs())/y_test)*100).mean()
print(f' mean percentage error for Random Forest Regressor is {mean_per_error}')
# Out:
# mean absolute error for Random Forest Regressor is [0.51258552]
# mean squared error for Random Forest Regressor is [0.49842313]
#  mean percentage error for Random Forest Regressor is 3.7783917627317574

# %% [markdown]
# This hyper-parameter otimization, changing n_estimators to 201 and max_Depth = 1  has resulted into increase in the error metrics.

# %% [markdown]
# #### One hot encoding

# %% [markdown]
# Now I will try to incorporate some categorical features into the dataset using pd.get_dummies function and will try to figure out if the categorical features have any effect on the target variable.

# %%
df_lin.head(3)
# Out:
#    index    borough   neighborhood  \
# 0      0  Manhattan  ALPHABET CITY
# 1      3  Manhattan  ALPHABET CITY
# 2      4  Manhattan  ALPHABET CITY
#
#                        building class category  block  lot  \
# 0  07 RENTALS - WALKUP APARTMENTS                 392    6
# 1  07 RENTALS - WALKUP APARTMENTS                 402   21
# 2  07 RENTALS - WALKUP APARTMENTS                 404   55
#
#   building class at present                 address zip code  \
# 0                        C2            153 AVENUE B    10009
# 1                        C4     154 EAST 7TH STREET    10009
# 2                        C2  301 EAST 10TH   STREET    10009
#
#    residential units  ...  gross square feet  year built  \
# 0           1.791759  ...           8.770284        1900
# 1           2.397895  ...           8.823795        1913
# 2           1.945910  ...           8.437067        1900
#
#    tax class at time of sale  building class at time of sale  sale price  \
# ...

# %%
df_lin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28040 entries, 0 to 28039
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   index                           28040 non-null  int64
#  1   borough                         28040 non-null  category
#  2   neighborhood                    28040 non-null  category
#  3   building class category         28040 non-null  category
#  4   block                           28040 non-null  int64
#  5   lot                             28040 non-null  int64
#  6   building class at present       28040 non-null  category
#  7   address                         28040 non-null  object
#  8   zip code                        28040 non-null  category
#  9   residential units               28040 non-null  float64
#  10  commercial units                28040 non-null  float64
#  11  total units                     28040 non-null  float64
# ...

# %%
#renaming the column
df_lin.rename({'tax class at present 2': 'tax class at present'}, axis=1, inplace=True)

# %%
df_lin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28040 entries, 0 to 28039
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   index                           28040 non-null  int64
#  1   borough                         28040 non-null  category
#  2   neighborhood                    28040 non-null  category
#  3   building class category         28040 non-null  category
#  4   block                           28040 non-null  int64
#  5   lot                             28040 non-null  int64
#  6   building class at present       28040 non-null  category
#  7   address                         28040 non-null  object
#  8   zip code                        28040 non-null  category
#  9   residential units               28040 non-null  float64
#  10  commercial units                28040 non-null  float64
#  11  total units                     28040 non-null  float64
# ...

# %% [markdown]
# # Inclusion of Categorical Variables
# #### Using One Hot Encoding

# %%
# using pd.dummies to convert the categorical columns into binary
borough_dum = pd.get_dummies(df_lin['borough']).rename(columns=lambda x: 'borough' + str(x))
tax_class_at_present_dum = pd.get_dummies(df_lin['tax class at present']).rename(columns=lambda x: 'tax class at present' + str(x))

# %% [markdown]
# Since we know from the data visualisation that one family dwellings and two family dwellings are making the most of market share , so I decided to convert them into main two columns and rest into other , we could also have converted four top building classes.

# %%
'''apt_list = ['01 ONE FAMILY DWELLINGS', '02 TWO FAMILY DWELLINGS']
df_lin['building class category'] = np.where(df_lin['building class category'] in apt_list, df_lin['building class category'], 'Other')
'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-185-8628151988a3> in <module>
#       1 apt_list = ['01 ONE FAMILY DWELLINGS', '02 TWO FAMILY DWELLINGS']
# ----> 2 df_lin['building class category'] = np.where(df_lin['building class category'] in apt_list, df_lin['building class category'], 'Other')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# adding them into the dataframe using concatanating 
df_lin = pd.concat([df_lin, borough_dum,tax_class_at_present_dum], axis=1)

# %%
df_lin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28040 entries, 0 to 28039
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   index                           28040 non-null  int64
#  1   borough                         28040 non-null  category
#  2   neighborhood                    28040 non-null  category
#  3   building class category         28040 non-null  category
#  4   block                           28040 non-null  int64
#  5   lot                             28040 non-null  int64
#  6   building class at present       28040 non-null  category
#  7   address                         28040 non-null  object
#  8   zip code                        28040 non-null  category
#  9   residential units               28040 non-null  float64
#  10  commercial units                28040 non-null  float64
#  11  total units                     28040 non-null  float64
# ...

# %% [markdown]
# Now we could have dropped Borough and Tax class at present , however I have kept these values for the data visualisation purposes.
# Now let us try to see if this inclusion of categorical variables has affected our models.

# %%
# lets declare our independent and dependent varaibles 

# declaring X 
X1 = df_lin[['land square feet','gross square feet','total units','residential units','commercial units','age of building', 'tax class at present4', 'tax class at present1','tax class at present2','boroughBronx','boroughBrooklyn','boroughManhattan','boroughQueens','boroughStaten Island']]
y1= df_lin['sale price']

# adding constant to X
X_withconstant1 = sm.add_constant(X1)

# modelling 
# 1. Instantiate model
lin_model1 = sm.OLS(y1, X_withconstant1)

# 2. Fit model
lin_model1_results = lin_model1.fit()

lin_model1_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sale price   R-squared:                       0.549
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     2838.
# Date:                Sun, 28 Jun 2020   Prob (F-statistic):               0.00
# Time:                        17:53:27   Log-Likelihood:                -24716.
# No. Observations:               28040   AIC:                         4.946e+04
# Df Residuals:                   28027   BIC:                         4.957e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# We can clearly see that the beta value corresponding to the Borough Manhattan has the highest value making it the most important factor responsible for the variation in the Sale price of the property as we already know that the average sale price in Manhattan is the highest.

# %%
# looking at the parameters 
print(lin_model1_results.params)

# residuals 
lin_model1_resids = lin_model1_results.resid 
lin_model1_resids.head()
# Out:
# const                    5.403370
# land square feet         0.130391
# gross square feet        0.595826
# total units             -0.142175
# residential units        0.101370
# commercial units         0.183307
# age of building         -0.005821
# tax class at present4    1.921065
# tax class at present1    1.645775
# tax class at present2    1.836530
# boroughBronx             0.559607
# boroughBrooklyn          1.149779
# boroughManhattan         2.102531
# boroughQueens            0.920887
# boroughStaten Island     0.670567
# dtype: float64
# 0    0.387367
# 1   -0.146044
# 2    0.741929
# 3   -0.059665
# 4    0.669084
# dtype: float64

# %%
# fitted values 

lin_model1_fittedvals = lin_model1_results.fittedvalues 
lin_model1_fittedvals.head()
# Out:
# 0    15.318993
# 1    15.331789
# 2    15.153023
# 3    15.036087
# 4    15.933412
# dtype: float64

# %%
#looking at the scatter plot of fitted values and residuals of the model 
plt.figure()
plt.scatter(lin_model1_fittedvals,lin_model1_resids)
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# We can see that there is a little difference in the plot between residuals and fitted values as compared to others and not much of a specific pattern is found i.e. our model is doing good.

# %% [markdown]
# As there are strong multicollinearity issues here, lets try to fit our baseline model and see how it works.

# %% [markdown]
# ### 1. Linear Regression

# %%
# test train split 
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.3, random_state=1)

#scaling 
# scale the data
from sklearn.preprocessing import StandardScaler
# instantiate 
scaler = StandardScaler()
# fit 
scaler.fit(X_train)
#transform
X_scaled_train = scaler.transform(X_train)
X_scaled_test = scaler.transform(X_test)

# %%
# %%time
# fitting the model

# Instantiate the model
regressor = LinearRegression()
# fit the model
regressor.fit(X_scaled_train, y_train)

# predicting the test result
y_pred_LR = regressor.predict(X_scaled_test)
# Out:
# Wall time: 12 ms

# %%
# calculating the r2 score 
score= r2_score(y_test,y_pred_LR)
print(f'r-squared score for Linear Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = mean_absolute_error(y_test, y_pred_LR)
print(f'mean absolute error for Linear regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = mean_squared_error(y_test, y_pred_LR)
print(f'mean squared error for Linear regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_LR).abs())/y_test)*100).mean()
print(f' mean percentage error for Linear Regressor is {mean_per_error}')
# Out:
# r-squared score for Linear Regressor is 0.545079603663839
# mean absolute error for Linear regressor is 0.40403537044427607
# mean squared error for Linear regressor is 0.348867347346728
#  mean percentage error for Linear Regressor is 3.0135172290780616

# %% [markdown]
# we can see that percentage error has decreased by incorporating the categorical variables.

# %% [markdown]
# Now lets try to fit other models as well.

# %% [markdown]
# As the Random Forest Regressor was doing good, so let us try to fit it on our data that includes the categorical variables as well.

# %% [markdown]
# ### 2. Random Forest

# %% [markdown]
# ##### Iteration 1
# Random Forest Regressor with the n_estimators in range 1 to 201 and max_depth = 1

# %%
# %%time
# Fitting on training set 
my_gridsearchcv.fit(X_scaled_train, y_train)
# Out:
# Wall time: 21 s
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=1,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
# ...

# %%
# best estimator
my_gridsearchcv.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=1, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=201, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
# making predictions 
y_pred_rf = my_gridsearchcv.predict(X_scaled_test)

# %%
# calculating the r2 score 
score= r2_score(y_test,y_pred_rf)
print(f'r-squared score for Random Forest Regressor is {score}')

# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred_rf).abs()).sum())/y_pred_rf.shape
print(f'mean absolute error for Random Forest Regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred_rf).abs())**2).sum())/y_pred_rf.shape
print(f'mean squared error for Random Forest Regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_rf).abs())/y_test)*100).mean()
print(f' mean percentage error for Random Forest Regressor is {mean_per_error}')
# Out:
# r-squared score for Random Forest Regressor is 0.35161481717266474
# mean absolute error for Random Forest Regressor is [0.51190742]
# mean squared error for Random Forest Regressor is [0.49723077]
#  mean percentage error for Random Forest Regressor is 3.773730250973518

# %% [markdown]
# ##### Iteration 2
# Random Forest Regressor with default n_estimators and max_depth

# %%
# %%time
# Instantiate 
RF_Regressor = RandomForestRegressor(criterion='mse')

# Fit the regressor
RF_Regressor.fit(X_scaled_train, y_train)

# Predict
y_pred_RF = RF_Regressor.predict(X_scaled_test)
# Out:
# Wall time: 7.03 s

# %%
# calculating the r2 score 
score= r2_score(y_test,y_pred_RF)
print(f'r-squared score for Random Forest Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred_RF).abs()).sum())/y_pred_RF.shape
print(f'mean absolute error for Random Forest regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred_RF).abs())**2).sum())/y_pred_RF.shape
print(f'mean squared error for Random Forest regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_RF).abs())/y_test)*100).mean()
print(f' mean percentage error for Random Forest Regressor is {mean_per_error}')
# Out:
# r-squared score for Random Forest Regressor is 0.5721067895570398
# mean absolute error for Random Forest regressor is [0.38694901]
# mean squared error for Random Forest regressor is [0.32814086]
#  mean percentage error for Random Forest Regressor is 2.886706145116832

# %% [markdown]
# We can see that with default parameters the Random Forest is working best out of all the iterations of the model

# %% [markdown]
# ### Lasso and Ridge using Grid Search

# %%
# %%time
# importing the Library
from sklearn.linear_model import Lasso

# declaring the parameters 
parameters={'alpha':np.arange(-100,210,10)}
# Instantiate the model and GS
Lasso_Regressor=Lasso()
Lasso_RegressorGS=GridSearchCV(Lasso_Regressor,parameters,scoring='neg_mean_squared_error',cv=5)
# Fit the model
Lasso_RegressorGS.fit(X_scaled_train,y_train)


# finding the best parameter
print(f'Best Parameter for the Lasso Regressor Model {Lasso_RegressorGS.best_params_}')
print(f'Best Score for the Lasso Regressor Model is {Lasso_RegressorGS.best_score_}')
# Out:
# C:\Users\16476\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\16476\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\16476\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2635.0749285805678, tolerance: 1.1796790676312385
#   positive)
# C:\Users\16476\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# ...

# %%
# making predictions 
y_pred_lasso = Lasso_RegressorGS.predict(X_scaled_test)
# calculating the r2 score 
score= r2_score(y_test,y_pred_lasso)
print(f'r-squared score for Lasso Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred_lasso).abs()).sum())/y_pred_lasso.shape
print(f'mean absolute error for Lasso Regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred_lasso).abs())**2).sum())/y_pred_lasso.shape
print(f'mean squared error for Lasso Regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_lasso).abs())/y_test)*100).mean()
print(f' mean percentage error for Lasso Regressor is {mean_per_error}')
# Out:
# r-squared score for Lasso Regressor is 0.5450796036638418
# mean absolute error for Lasso Regressor is [0.40403537]
# mean squared error for Lasso Regressor is [0.34886735]
#  mean percentage error for Lasso Regressor is 3.013517229078056

# %% [markdown]
# We can see that the error values have decreased using the categorical variables.

# %%
# %%time
# importing the library for Ridge 
from sklearn.linear_model import Ridge
# importing grid search 
from sklearn.model_selection import GridSearchCV
# importing the cross validation 
from sklearn.model_selection import cross_val_score

# declaring the parameters 
parameters={'alpha':np.arange(-100,210,10)}
# Instantiate the model and GS
Ridge_Regressor=Ridge()
Ridge_RegressorGS=GridSearchCV(Ridge_Regressor,parameters,scoring='neg_mean_squared_error',cv=5)
# Fit the model
Ridge_RegressorGS.fit(X_scaled_train,y_train)


# finding the best parameter
print(f'Best Parameter for the Ridge Regressor Model {Ridge_RegressorGS.best_params_}')
print(f'Best Score for the Ridge Regressor Model is {Ridge_RegressorGS.best_score_}')
# Out:
# C:\Users\16476\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=7.7863e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\16476\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=6.77319e-17): result may not be accurate.
#   overwrite_a=True).T
# Best Parameter for the Ridge Regressor Model {'alpha': 80}
# Best Score for the Ridge Regressor Model is -0.3398998512761856
# Wall time: 935 ms

# %%
# making predictions 
y_pred_ridge = Ridge_RegressorGS.predict(X_scaled_test)
# calculating the r2 score 
score= r2_score(y_test,y_pred)
print(f'r-squared score for Ridge Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred_ridge).abs()).sum())/y_pred_ridge.shape
print(f'mean absolute error for Ridge Regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred_ridge).abs())**2).sum())/y_pred_ridge.shape
print(f'mean squared error for Ridge Regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_ridge).abs())/y_test)*100).mean()
print(f' mean percentage error for Ridge Regressor is {mean_per_error}')
# Out:
# r-squared score for Ridge Regressor is -9.115774834200785e-05
# mean absolute error for Ridge Regressor is [0.4038862]
# mean squared error for Ridge Regressor is [0.34840173]
#  mean percentage error for Ridge Regressor is 3.0123502045566743

# %% [markdown]
# ### Decision Tree

# %%
# %%time
# importing the library
from sklearn.tree import DecisionTreeRegressor

# Instantiate the model
DT_Regressor = DecisionTreeRegressor(random_state=0)

# Fit the regressor
DT_Regressor.fit(X_scaled_train, y_train)

# Predict
y_pred_DT = DT_Regressor.predict(X_scaled_test)
# Out:
# Wall time: 97.7 ms

# %%
# calculating the r2 score 
score= r2_score(y_test,y_pred_DT)
print(f'r-squared score for Decision Tree Regressor is {score}')
# calculating the mean absolute error
mean_abs_error = (((y_test - y_pred_DT).abs()).sum())/y_pred_DT.shape
print(f'mean absolute error for Decision Tree regressor is {mean_abs_error}')
# calculating the mean squared error
mean_sq_error = ((((y_test - y_pred_DT).abs())**2).sum())/y_pred_DT.shape
print(f'mean squared error for Decision Tree regressor is {mean_sq_error}')
# calculating mean percentage error 
mean_per_error = ((((y_test - y_pred_DT).abs())/y_test)*100).mean()
print(f' mean percentage error for Random Forest Regressor is {mean_per_error}')
# Out:
# r-squared score for Decision Tree Regressor is 0.21477438481473377
# mean absolute error for Decision Tree regressor is [0.5146729]
# mean squared error for Decision Tree regressor is [0.60217036]
#  mean percentage error for Random Forest Regressor is 3.8228197636183174

# %%
df_lin.shape
# Out:
# (28040, 31)

# %% [markdown]
# 1. Conclusion and Findings:
#
#         In conclusion, Random forest Regressor works out to be the best model in the prediction of the sale price with only 2.89 % in Case 2. With the inclusion of more information about the dataset, we can see that the predictions have become better. When the Categorical variables like borough was added, the Beta value for the Borough Manhattan was maximum which was maximum for gross square feet before without categorical features. Thus, we can conclude that Borough in which the property is located is an important factor in the prediction of the sale price. Also, tax class of the property is an important factor as well, out shadowing other factors as beta values corresponding to them were also higher explaining that they are responsible for more variation in the sale price.
#         Wihtout the categorical variables, ```gross square feet``` was the most important factor in predicting the sale price, but after inclusding Borough and Tax class of the property, the variation that borough brings to the target is a lot  more than the gross square feet as Beta value corresponding to the Borough is 2.1 and for gross square feet it is 0.59
#         From the data visualisations, it can be seen that Manhattan is the most expensive place to live in New York as it has highest average price of properties.
#         Class 4 in Tax Class of properties i.e. Offices, factories and Warehouses brings maximum variation in the sale price of the properties.
#         Class 2 i.e Condominimums and coperatives are on second place and Class 1 i.e. one-,
#         two-, and three-family homes and small stores or offices with one or two
#         attached apartments), vacant land that is zoned for residential use, and most
#         condominiums that are not more than three stories brings least variation in terms of tax class of property at present.
#         ```residential units``` and ```commercial units``` are not bringing much of the difference. So we can try to fit the model without them as well and compare the results.
#         In 2017, Brooklyn has registered the highest number of sales, the visualisation is in Tableau workheet attached.
#
#
#
# 2. Summary and Future Directions:
#
#         Summing up, Inclusion of categorical variables have improved the model score and decreased the errors in predictions made for the sale price, In terms of modelling for Random Forest model, the regularisation has increased the error. Linear regression is working better with categorical variables, so we can include more categorical features like building class at present and perform the iterations. Also, neural networks can be employed, and code can be made more efficient. The way of calculation for errors can be improved.
